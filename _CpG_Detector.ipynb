# %% [markdown]
# # Part 1: Build CpG Detector
#
# Here we have a simple problem, given a DNA sequence (of N, A, C, G, T), count the number of CpGs in the sequence (consecutive CGs).

# %%
from typing import Sequence
from functools import partial
import random
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import random
from sklearn.metrics import r2_score

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
# DO NOT CHANGE HERE
def set_seed(seed=13):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(13)

# Use this for getting x label
def rand_sequence(n_seqs: int, seq_len: int=128) -> Sequence[int]:
    for i in range(n_seqs):
        yield [random.randint(0, 4) for _ in range(seq_len)]

# Use this for getting y label
def count_cpgs(seq: str) -> int:
    cgs = 0
    for i in range(0, len(seq) - 1):
        dimer = seq[i:i+2]
        # note that seq is a string, not a list
        if dimer == "CG":
            cgs += 1
    return cgs

# Alphabet helpers   
alphabet = 'NACGT'
dna2int = { a: i for a, i in zip(alphabet, range(5))}
int2dna = { i: a for a, i in zip(alphabet, range(5))}

intseq_to_dnaseq = partial(map, int2dna.get)
dnaseq_to_intseq = partial(map, dna2int.get)

# %%
# two datasets for training and evaluation
# training data scale we set to 2048
# we test on 512

def prepare_data(num_samples=100):
    X_dna_seqs_train = list(rand_sequence(num_samples))
    """
    hint:
        1. You can check X_dna_seqs_train by print, the data is ids which is your training X 
        2. You first convert ids back to DNA sequence
        3. Then you run count_cpgs which will yield CGs counts - this will be the labels (Y)
    """
    #step2
    temp = list(map(intseq_to_dnaseq, X_dna_seqs_train)) # use intseq_to_dnaseq here to convert ids back to DNA seqs
    dna_seqs = [''.join(seq) for seq in temp]
    #step3
    y_dna_seqs = [count_cpgs(seq) for seq in dna_seqs] # use count_cpgs here to generate labels with temp generated in step2
    
    return torch.tensor(X_dna_seqs_train).long(), torch.tensor(y_dna_seqs).float().unsqueeze(1)
    
train_x, train_y = prepare_data(2048)
test_x, test_y = prepare_data(512)

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 6))
axs[0].hist(train_y.numpy(), bins=int(train_y.max()-train_y.min()), align='left')
axs[0].set_ylabel('Frequency')
axs[0].set_xlabel('CpGs count')
axs[0].set_title('Training label distribution')
axs[0].grid(alpha=0.2)

axs[1].hist(test_y.numpy(), bins=int(test_y.max()-test_y.min()), align='left')
axs[1].set_ylabel('Frequency')
axs[1].set_xlabel('CpGs count')
axs[1].set_title('Test label distribution')
axs[1].grid(alpha=0.2)
plt.show()

# %%
print(len(train_x), len(train_y), len(test_x), len(test_y))
# Out:
# 2048 2048 512 512

# %%
train_x.size(), test_x.size()
# Out:
# (torch.Size([2048, 128]), torch.Size([512, 128]))

# %%
# some config
LSTM_HIDDEN = 16
LSTM_LAYER = 3
BATCH_SIZE = 128
LEARNING_RATE = 0.001
NUM_EPOCHS = 300
VOCAB_SIZE = 5
OUTPUT_SIZE = 1

# %%
# create Tensor Datasets and Data Loaders
train_dataset = TensorDataset(train_x, train_y)
test_dataset = TensorDataset(test_x, test_y)

train_data_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
test_data_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)

# %%
class CpGPredictor(torch.nn.Module):
    ''' Simple model that uses a LSTM to count the number of CpGs in a sequence '''
    def __init__(self, vocab_size, embedding_dim, hidden_size, num_layers, output_size):
        super(CpGPredictor, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_size = output_size

        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        self.lstm = nn.LSTM(embedding_dim, hidden_size, num_layers, batch_first=True)
        self.classifier = nn.Linear(hidden_size, output_size)

    def forward(self, x, hc=None):
        # Apply normalization along the sequence dimension
        x = self.embedding(x)

        # Initialize hidden state and cell state if not provided
        if hc is None:
            hc = self.init_hidden(x.size(0))

        # LSTM layer
        out, _ = self.lstm(x, hc)

        # Use the output from the last time step for classification
        out = self.classifier(out[:, -1, :])

        return out
    
    def init_hidden(self, batch_size):
        # Initialize hidden state and cell state with zeros
        return (torch.zeros(self.num_layers, batch_size, self.hidden_size),
                torch.zeros(self.num_layers, batch_size, self.hidden_size))

# %%
# init model / loss function / optimizer etc.
model = CpGPredictor(vocab_size=VOCAB_SIZE, embedding_dim=16, hidden_size=LSTM_HIDDEN, num_layers=LSTM_LAYER, output_size=OUTPUT_SIZE)
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
# training (you can modify the code below)

# Initialize Losses
train_losses = []
test_losses = []

train_r2 = []
test_r2 = []


for epoch in range(NUM_EPOCHS):
    
    # Set the model on training mode.
    model.train()

    # Initialize batch losses
    train_batch_losses = []
    test_batch_losses = []

    train_batch_r2 = []
    test_batch_r2 = []
    
    for X, y in train_data_loader:
        #TODO complete training loop

        # Initialize hidden state
        hc = model.init_hidden(X.size(0))

        y_hat = model(X, hc)

        # Compute Loss
        loss = loss_fn(y_hat, y)

        # Compute r2
        r2 = r2_score(y.detach().numpy(), y_hat.detach().numpy())

        # Backprop and Optimzation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Store the batch loss
        train_batch_losses.append(loss.item())
        train_batch_r2.append(r2)
    
    # Average the batch losses and store as a global loss
    train_losses.append(np.mean(train_batch_losses))
    train_r2.append(np.mean(train_batch_r2))

    # Set the model on evaluation mode.
    model.eval()
    for X, y in test_data_loader:
        with torch.no_grad():
            # Initialize hidden state
            hc = model.init_hidden(X.size(0))

            y_hat = model(X, hc)
            loss = loss_fn(y_hat, y)
            r2 = r2_score(y.detach().numpy(), y_hat.detach().numpy())

            test_batch_losses.append(loss.item())
            test_batch_r2.append(r2)

    # Average loss across the batches
    test_losses.append(np.mean(test_batch_losses))
    test_r2.append(np.mean(test_batch_r2))
    
    print(f'Epoch [{epoch + 1}/{NUM_EPOCHS}], Train Loss: {train_losses[-1]:.4f}, Test Loss: {test_losses[-1]:.4f}, Train_r2: {train_r2[-1]:.4f}, Test_r2: {test_r2[-1]:4f}')
# Out:
# Epoch [1/300], Train Loss: 31.2941, Test Loss: 29.7515, Train_r2: -6.6470, Test_r2: -6.234334
# Epoch [2/300], Train Loss: 28.6106, Test Loss: 25.9803, Train_r2: -5.9008, Test_r2: -5.377341
# Epoch [3/300], Train Loss: 23.7975, Test Loss: 20.5600, Train_r2: -4.7699, Test_r2: -3.990077
# Epoch [4/300], Train Loss: 18.3987, Test Loss: 15.4144, Train_r2: -3.4859, Test_r2: -2.736378
# Epoch [5/300], Train Loss: 13.6799, Test Loss: 11.4195, Train_r2: -2.3155, Test_r2: -1.758352
# Epoch [6/300], Train Loss: 10.3994, Test Loss: 9.0060, Train_r2: -1.5103, Test_r2: -1.196386
# Epoch [7/300], Train Loss: 8.4417, Test Loss: 7.5199, Train_r2: -1.0481, Test_r2: -0.827726
# Epoch [8/300], Train Loss: 7.1813, Test Loss: 6.5163, Train_r2: -0.7301, Test_r2: -0.578432
# Epoch [9/300], Train Loss: 6.3116, Test Loss: 5.8130, Train_r2: -0.5150, Test_r2: -0.413949
# Epoch [10/300], Train Loss: 5.6891, Test Loss: 5.3144, Train_r2: -0.3754, Test_r2: -0.282352
# Epoch [11/300], Train Loss: 5.2465, Test Loss: 4.9535, Train_r2: -0.2594, Test_r2: -0.192932
# Epoch [12/300], Train Loss: 4.9288, Test Loss: 4.6945, Train_r2: -0.1900, Test_r2: -0.132816
# Epoch [13/300], Train Loss: 4.6970, Test Loss: 4.5152, Train_r2: -0.1288, Test_r2: -0.092917
# Epoch [14/300], Train Loss: 4.5316, Test Loss: 4.3940, Train_r2: -0.0962, Test_r2: -0.061911
# Epoch [15/300], Train Loss: 4.4192, Test Loss: 4.3099, Train_r2: -0.0646, Test_r2: -0.040007
# Epoch [16/300], Train Loss: 4.3416, Test Loss: 4.2522, Train_r2: -0.0504, Test_r2: -0.038391
# Epoch [17/300], Train Loss: 4.2890, Test Loss: 4.2137, Train_r2: -0.0287, Test_r2: -0.017517
# Epoch [18/300], Train Loss: 4.2530, Test Loss: 4.1901, Train_r2: -0.0195, Test_r2: -0.010368
# Epoch [19/300], Train Loss: 4.2301, Test Loss: 4.1752, Train_r2: -0.0136, Test_r2: -0.007489
# Epoch [20/300], Train Loss: 4.2149, Test Loss: 4.1667, Train_r2: -0.0123, Test_r2: -0.013832
# Epoch [21/300], Train Loss: 4.2069, Test Loss: 4.1609, Train_r2: -0.0065, Test_r2: -0.005024
# Epoch [22/300], Train Loss: 4.1999, Test Loss: 4.1588, Train_r2: -0.0094, Test_r2: -0.008570
# Epoch [23/300], Train Loss: 4.1972, Test Loss: 4.1573, Train_r2: -0.0065, Test_r2: -0.003303
# Epoch [24/300], Train Loss: 4.1948, Test Loss: 4.1569, Train_r2: -0.0049, Test_r2: -0.004981
# Epoch [25/300], Train Loss: 4.1946, Test Loss: 4.1570, Train_r2: -0.0082, Test_r2: -0.009292
# Epoch [26/300], Train Loss: 4.1936, Test Loss: 4.1569, Train_r2: -0.0111, Test_r2: -0.000597
# Epoch [27/300], Train Loss: 4.1928, Test Loss: 4.1573, Train_r2: -0.0050, Test_r2: -0.009131
# Epoch [28/300], Train Loss: 4.1928, Test Loss: 4.1575, Train_r2: -0.0115, Test_r2: -0.001571
# Epoch [29/300], Train Loss: 4.1925, Test Loss: 4.1578, Train_r2: -0.0040, Test_r2: -0.020380
# Epoch [30/300], Train Loss: 4.1924, Test Loss: 4.1577, Train_r2: -0.0066, Test_r2: -0.001916
# Epoch [31/300], Train Loss: 4.1924, Test Loss: 4.1579, Train_r2: -0.0108, Test_r2: -0.001897
# Epoch [32/300], Train Loss: 4.1924, Test Loss: 4.1580, Train_r2: -0.0084, Test_r2: -0.011880
# Epoch [33/300], Train Loss: 4.1923, Test Loss: 4.1583, Train_r2: -0.0083, Test_r2: -0.007920
# Epoch [34/300], Train Loss: 4.1927, Test Loss: 4.1584, Train_r2: -0.0077, Test_r2: -0.008743
# Epoch [35/300], Train Loss: 4.1922, Test Loss: 4.1583, Train_r2: -0.0050, Test_r2: -0.005249
# Epoch [36/300], Train Loss: 4.1923, Test Loss: 4.1582, Train_r2: -0.0061, Test_r2: -0.007043
# Epoch [37/300], Train Loss: 4.1924, Test Loss: 4.1584, Train_r2: -0.0063, Test_r2: -0.012146
# Epoch [38/300], Train Loss: 4.1923, Test Loss: 4.1583, Train_r2: -0.0057, Test_r2: -0.010487
# Epoch [39/300], Train Loss: 4.1927, Test Loss: 4.1578, Train_r2: -0.0051, Test_r2: -0.006645
# Epoch [40/300], Train Loss: 4.1926, Test Loss: 4.1584, Train_r2: -0.0107, Test_r2: -0.001614
# Epoch [41/300], Train Loss: 4.1928, Test Loss: 4.1589, Train_r2: -0.0067, Test_r2: -0.009852
# Epoch [42/300], Train Loss: 4.1923, Test Loss: 4.1582, Train_r2: -0.0121, Test_r2: -0.005291
# Epoch [43/300], Train Loss: 4.1923, Test Loss: 4.1582, Train_r2: -0.0047, Test_r2: -0.002553
# Epoch [44/300], Train Loss: 4.1924, Test Loss: 4.1581, Train_r2: -0.0078, Test_r2: -0.008578
# Epoch [45/300], Train Loss: 4.1925, Test Loss: 4.1578, Train_r2: -0.0059, Test_r2: -0.000947
# Epoch [46/300], Train Loss: 4.1923, Test Loss: 4.1580, Train_r2: -0.0060, Test_r2: -0.003297
# Epoch [47/300], Train Loss: 4.1923, Test Loss: 4.1584, Train_r2: -0.0065, Test_r2: -0.006938
# Epoch [48/300], Train Loss: 4.1925, Test Loss: 4.1588, Train_r2: -0.0113, Test_r2: -0.001804
# Epoch [49/300], Train Loss: 4.1925, Test Loss: 4.1582, Train_r2: -0.0073, Test_r2: -0.001235
# Epoch [50/300], Train Loss: 4.1926, Test Loss: 4.1581, Train_r2: -0.0061, Test_r2: -0.011544
# Epoch [51/300], Train Loss: 4.1929, Test Loss: 4.1588, Train_r2: -0.0112, Test_r2: -0.004001
# Epoch [52/300], Train Loss: 4.1931, Test Loss: 4.1579, Train_r2: -0.0067, Test_r2: -0.002758
# Epoch [53/300], Train Loss: 4.1929, Test Loss: 4.1586, Train_r2: -0.0099, Test_r2: -0.002913
# Epoch [54/300], Train Loss: 4.1929, Test Loss: 4.1590, Train_r2: -0.0099, Test_r2: -0.001094
# Epoch [55/300], Train Loss: 4.1928, Test Loss: 4.1579, Train_r2: -0.0105, Test_r2: -0.001139
# Epoch [56/300], Train Loss: 4.1925, Test Loss: 4.1583, Train_r2: -0.0087, Test_r2: -0.009477
# Epoch [57/300], Train Loss: 4.1924, Test Loss: 4.1581, Train_r2: -0.0086, Test_r2: -0.002234
# Epoch [58/300], Train Loss: 4.1925, Test Loss: 4.1582, Train_r2: -0.0132, Test_r2: -0.005180
# Epoch [59/300], Train Loss: 4.1923, Test Loss: 4.1580, Train_r2: -0.0047, Test_r2: -0.000968
# Epoch [60/300], Train Loss: 4.1926, Test Loss: 4.1580, Train_r2: -0.0075, Test_r2: -0.001526
# Epoch [61/300], Train Loss: 4.1925, Test Loss: 4.1580, Train_r2: -0.0094, Test_r2: -0.008654
# Epoch [62/300], Train Loss: 4.1922, Test Loss: 4.1582, Train_r2: -0.0057, Test_r2: -0.003854
# Epoch [63/300], Train Loss: 4.1927, Test Loss: 4.1589, Train_r2: -0.0138, Test_r2: -0.015306
# Epoch [64/300], Train Loss: 4.1924, Test Loss: 4.1586, Train_r2: -0.0131, Test_r2: -0.011763
# Epoch [65/300], Train Loss: 4.1925, Test Loss: 4.1580, Train_r2: -0.0070, Test_r2: -0.002366
# Epoch [66/300], Train Loss: 4.1925, Test Loss: 4.1585, Train_r2: -0.0075, Test_r2: -0.009232
# Epoch [67/300], Train Loss: 4.1926, Test Loss: 4.1580, Train_r2: -0.0059, Test_r2: -0.001633
# Epoch [68/300], Train Loss: 4.1931, Test Loss: 4.1589, Train_r2: -0.0134, Test_r2: -0.011910
# Epoch [69/300], Train Loss: 4.1924, Test Loss: 4.1587, Train_r2: -0.0089, Test_r2: -0.018900
# Epoch [70/300], Train Loss: 4.1923, Test Loss: 4.1582, Train_r2: -0.0117, Test_r2: -0.002368
# Epoch [71/300], Train Loss: 4.1928, Test Loss: 4.1577, Train_r2: -0.0090, Test_r2: -0.016249
# Epoch [72/300], Train Loss: 4.1924, Test Loss: 4.1580, Train_r2: -0.0115, Test_r2: -0.004127
# Epoch [73/300], Train Loss: 4.1926, Test Loss: 4.1583, Train_r2: -0.0113, Test_r2: -0.002918
# Epoch [74/300], Train Loss: 4.1925, Test Loss: 4.1588, Train_r2: -0.0044, Test_r2: -0.010139
# Epoch [75/300], Train Loss: 4.1925, Test Loss: 4.1587, Train_r2: -0.0059, Test_r2: -0.002256
# Epoch [76/300], Train Loss: 4.1922, Test Loss: 4.1583, Train_r2: -0.0043, Test_r2: -0.004843
# Epoch [77/300], Train Loss: 4.1929, Test Loss: 4.1589, Train_r2: -0.0126, Test_r2: -0.002534
# Epoch [78/300], Train Loss: 4.1922, Test Loss: 4.1583, Train_r2: -0.0071, Test_r2: -0.008820
# Epoch [79/300], Train Loss: 4.1923, Test Loss: 4.1582, Train_r2: -0.0116, Test_r2: -0.007899
# Epoch [80/300], Train Loss: 4.1925, Test Loss: 4.1577, Train_r2: -0.0066, Test_r2: -0.002700
# Epoch [81/300], Train Loss: 4.1924, Test Loss: 4.1579, Train_r2: -0.0099, Test_r2: -0.004104
# Epoch [82/300], Train Loss: 4.1937, Test Loss: 4.1577, Train_r2: -0.0090, Test_r2: -0.001278
# Epoch [83/300], Train Loss: 4.1926, Test Loss: 4.1587, Train_r2: -0.0085, Test_r2: -0.002255
# Epoch [84/300], Train Loss: 4.1924, Test Loss: 4.1585, Train_r2: -0.0080, Test_r2: -0.003196
# Epoch [85/300], Train Loss: 4.1925, Test Loss: 4.1581, Train_r2: -0.0075, Test_r2: -0.002961
# Epoch [86/300], Train Loss: 4.1924, Test Loss: 4.1587, Train_r2: -0.0082, Test_r2: -0.005991
# Epoch [87/300], Train Loss: 4.1926, Test Loss: 4.1583, Train_r2: -0.0057, Test_r2: -0.001502
# Epoch [88/300], Train Loss: 4.1924, Test Loss: 4.1584, Train_r2: -0.0057, Test_r2: -0.002290
# Epoch [89/300], Train Loss: 4.1928, Test Loss: 4.1588, Train_r2: -0.0049, Test_r2: -0.008430
# Epoch [90/300], Train Loss: 4.1923, Test Loss: 4.1581, Train_r2: -0.0098, Test_r2: -0.007058
# Epoch [91/300], Train Loss: 4.1932, Test Loss: 4.1589, Train_r2: -0.0090, Test_r2: -0.004566
# Epoch [92/300], Train Loss: 4.1922, Test Loss: 4.1584, Train_r2: -0.0076, Test_r2: -0.009614
# Epoch [93/300], Train Loss: 4.1931, Test Loss: 4.1578, Train_r2: -0.0201, Test_r2: -0.003667
# Epoch [94/300], Train Loss: 4.1925, Test Loss: 4.1577, Train_r2: -0.0115, Test_r2: -0.002651
# Epoch [95/300], Train Loss: 4.1925, Test Loss: 4.1583, Train_r2: -0.0080, Test_r2: -0.004009
# Epoch [96/300], Train Loss: 4.1924, Test Loss: 4.1579, Train_r2: -0.0072, Test_r2: -0.010724
# Epoch [97/300], Train Loss: 4.1923, Test Loss: 4.1582, Train_r2: -0.0054, Test_r2: -0.005718
# Epoch [98/300], Train Loss: 4.1923, Test Loss: 4.1583, Train_r2: -0.0055, Test_r2: -0.001614
# Epoch [99/300], Train Loss: 4.1924, Test Loss: 4.1581, Train_r2: -0.0069, Test_r2: -0.002078
# Epoch [100/300], Train Loss: 4.1926, Test Loss: 4.1586, Train_r2: -0.0101, Test_r2: -0.002942
# Epoch [101/300], Train Loss: 4.1923, Test Loss: 4.1584, Train_r2: -0.0048, Test_r2: -0.002148
# Epoch [102/300], Train Loss: 4.1926, Test Loss: 4.1586, Train_r2: -0.0093, Test_r2: -0.008549
# Epoch [103/300], Train Loss: 4.1926, Test Loss: 4.1581, Train_r2: -0.0076, Test_r2: -0.014817
# Epoch [104/300], Train Loss: 4.1925, Test Loss: 4.1582, Train_r2: -0.0115, Test_r2: -0.004007
# Epoch [105/300], Train Loss: 4.1924, Test Loss: 4.1586, Train_r2: -0.0052, Test_r2: -0.014344
# Epoch [106/300], Train Loss: 4.1928, Test Loss: 4.1578, Train_r2: -0.0045, Test_r2: -0.007179
# Epoch [107/300], Train Loss: 4.1928, Test Loss: 4.1579, Train_r2: -0.0075, Test_r2: -0.005374
# Epoch [108/300], Train Loss: 4.1927, Test Loss: 4.1579, Train_r2: -0.0088, Test_r2: -0.015445
# Epoch [109/300], Train Loss: 4.1929, Test Loss: 4.1590, Train_r2: -0.0072, Test_r2: -0.005721
# Epoch [110/300], Train Loss: 4.1928, Test Loss: 4.1581, Train_r2: -0.0113, Test_r2: -0.004224
# Epoch [111/300], Train Loss: 4.1923, Test Loss: 4.1581, Train_r2: -0.0091, Test_r2: -0.008251
# Epoch [112/300], Train Loss: 4.1929, Test Loss: 4.1582, Train_r2: -0.0114, Test_r2: -0.008605
# Epoch [113/300], Train Loss: 4.1925, Test Loss: 4.1586, Train_r2: -0.0072, Test_r2: -0.009175
# Epoch [114/300], Train Loss: 4.1924, Test Loss: 4.1587, Train_r2: -0.0085, Test_r2: -0.012930
# Epoch [115/300], Train Loss: 4.1925, Test Loss: 4.1583, Train_r2: -0.0033, Test_r2: -0.017273
# Epoch [116/300], Train Loss: 4.1931, Test Loss: 4.1578, Train_r2: -0.0128, Test_r2: -0.004477
# Epoch [117/300], Train Loss: 4.1931, Test Loss: 4.1576, Train_r2: -0.0097, Test_r2: -0.009602
# Epoch [118/300], Train Loss: 4.1930, Test Loss: 4.1589, Train_r2: -0.0080, Test_r2: -0.002471
# Epoch [119/300], Train Loss: 4.1929, Test Loss: 4.1594, Train_r2: -0.0062, Test_r2: -0.006189
# Epoch [120/300], Train Loss: 4.1924, Test Loss: 4.1581, Train_r2: -0.0108, Test_r2: -0.005208
# Epoch [121/300], Train Loss: 4.1924, Test Loss: 4.1578, Train_r2: -0.0044, Test_r2: -0.016887
# Epoch [122/300], Train Loss: 4.1928, Test Loss: 4.1575, Train_r2: -0.0104, Test_r2: -0.001080
# Epoch [123/300], Train Loss: 4.1923, Test Loss: 4.1580, Train_r2: -0.0060, Test_r2: -0.003907
# Epoch [124/300], Train Loss: 4.1926, Test Loss: 4.1581, Train_r2: -0.0079, Test_r2: -0.013704
# Epoch [125/300], Train Loss: 4.1921, Test Loss: 4.1590, Train_r2: -0.0080, Test_r2: -0.004122
# Epoch [126/300], Train Loss: 4.1925, Test Loss: 4.1592, Train_r2: -0.0104, Test_r2: -0.007084
# Epoch [127/300], Train Loss: 4.1928, Test Loss: 4.1580, Train_r2: -0.0077, Test_r2: -0.002393
# Epoch [128/300], Train Loss: 4.1926, Test Loss: 4.1578, Train_r2: -0.0074, Test_r2: -0.013425
# Epoch [129/300], Train Loss: 4.1928, Test Loss: 4.1592, Train_r2: -0.0028, Test_r2: -0.007287
# Epoch [130/300], Train Loss: 4.1927, Test Loss: 4.1581, Train_r2: -0.0082, Test_r2: -0.002810
# Epoch [131/300], Train Loss: 4.1924, Test Loss: 4.1582, Train_r2: -0.0074, Test_r2: -0.003528
# Epoch [132/300], Train Loss: 4.1925, Test Loss: 4.1579, Train_r2: -0.0037, Test_r2: -0.012615
# Epoch [133/300], Train Loss: 4.1922, Test Loss: 4.1586, Train_r2: -0.0053, Test_r2: -0.012817
# Epoch [134/300], Train Loss: 4.1924, Test Loss: 4.1587, Train_r2: -0.0064, Test_r2: -0.004503
# Epoch [135/300], Train Loss: 4.1928, Test Loss: 4.1586, Train_r2: -0.0101, Test_r2: -0.008826
# Epoch [136/300], Train Loss: 4.1924, Test Loss: 4.1579, Train_r2: -0.0076, Test_r2: -0.003773
# Epoch [137/300], Train Loss: 4.1930, Test Loss: 4.1587, Train_r2: -0.0121, Test_r2: -0.028536
# Epoch [138/300], Train Loss: 4.1925, Test Loss: 4.1578, Train_r2: -0.0072, Test_r2: -0.005393
# Epoch [139/300], Train Loss: 4.1925, Test Loss: 4.1581, Train_r2: -0.0062, Test_r2: -0.019553
# Epoch [140/300], Train Loss: 4.1924, Test Loss: 4.1583, Train_r2: -0.0042, Test_r2: -0.005409
# Epoch [141/300], Train Loss: 4.1925, Test Loss: 4.1578, Train_r2: -0.0073, Test_r2: -0.009264
# Epoch [142/300], Train Loss: 4.1926, Test Loss: 4.1579, Train_r2: -0.0050, Test_r2: -0.008548
# Epoch [143/300], Train Loss: 4.1924, Test Loss: 4.1587, Train_r2: -0.0079, Test_r2: -0.004880
# Epoch [144/300], Train Loss: 4.1924, Test Loss: 4.1583, Train_r2: -0.0064, Test_r2: -0.002039
# Epoch [145/300], Train Loss: 4.1925, Test Loss: 4.1579, Train_r2: -0.0036, Test_r2: -0.003998
# Epoch [146/300], Train Loss: 4.1943, Test Loss: 4.1586, Train_r2: -0.0153, Test_r2: -0.008748
# Epoch [147/300], Train Loss: 4.1929, Test Loss: 4.1575, Train_r2: -0.0088, Test_r2: -0.004667
# Epoch [148/300], Train Loss: 4.1933, Test Loss: 4.1592, Train_r2: -0.0105, Test_r2: -0.003056
# Epoch [149/300], Train Loss: 4.1928, Test Loss: 4.1577, Train_r2: -0.0075, Test_r2: -0.007108
# Epoch [150/300], Train Loss: 4.1925, Test Loss: 4.1583, Train_r2: -0.0057, Test_r2: -0.005223
# Epoch [151/300], Train Loss: 4.1925, Test Loss: 4.1578, Train_r2: -0.0071, Test_r2: -0.005165
# Epoch [152/300], Train Loss: 4.1923, Test Loss: 4.1583, Train_r2: -0.0052, Test_r2: -0.010066
# Epoch [153/300], Train Loss: 4.1925, Test Loss: 4.1586, Train_r2: -0.0101, Test_r2: -0.006386
# Epoch [154/300], Train Loss: 4.1928, Test Loss: 4.1588, Train_r2: -0.0073, Test_r2: -0.000985
# Epoch [155/300], Train Loss: 4.1927, Test Loss: 4.1580, Train_r2: -0.0127, Test_r2: -0.002918
# Epoch [156/300], Train Loss: 4.1925, Test Loss: 4.1579, Train_r2: -0.0077, Test_r2: -0.001449
# Epoch [157/300], Train Loss: 4.1932, Test Loss: 4.1588, Train_r2: -0.0082, Test_r2: -0.004470
# Epoch [158/300], Train Loss: 4.1936, Test Loss: 4.1574, Train_r2: -0.0126, Test_r2: -0.001487
# Epoch [159/300], Train Loss: 4.1930, Test Loss: 4.1593, Train_r2: -0.0071, Test_r2: -0.005949
# Epoch [160/300], Train Loss: 4.1928, Test Loss: 4.1587, Train_r2: -0.0096, Test_r2: -0.003812
# Epoch [161/300], Train Loss: 4.1928, Test Loss: 4.1587, Train_r2: -0.0082, Test_r2: -0.012057
# Epoch [162/300], Train Loss: 4.1929, Test Loss: 4.1580, Train_r2: -0.0075, Test_r2: -0.002003
# Epoch [163/300], Train Loss: 4.1936, Test Loss: 4.1573, Train_r2: -0.0067, Test_r2: -0.003166
# Epoch [164/300], Train Loss: 4.1931, Test Loss: 4.1592, Train_r2: -0.0071, Test_r2: -0.003489
# Epoch [165/300], Train Loss: 4.1932, Test Loss: 4.1592, Train_r2: -0.0111, Test_r2: -0.013442
# Epoch [166/300], Train Loss: 4.1924, Test Loss: 4.1584, Train_r2: -0.0042, Test_r2: -0.021066
# Epoch [167/300], Train Loss: 4.1926, Test Loss: 4.1577, Train_r2: -0.0106, Test_r2: -0.000938
# Epoch [168/300], Train Loss: 4.1924, Test Loss: 4.1575, Train_r2: -0.0060, Test_r2: -0.026826
# Epoch [169/300], Train Loss: 4.1932, Test Loss: 4.1580, Train_r2: -0.0107, Test_r2: -0.003536
# Epoch [170/300], Train Loss: 4.1927, Test Loss: 4.1582, Train_r2: -0.0123, Test_r2: -0.002937
# Epoch [171/300], Train Loss: 4.1924, Test Loss: 4.1586, Train_r2: -0.0049, Test_r2: -0.003219
# Epoch [172/300], Train Loss: 4.1931, Test Loss: 4.1576, Train_r2: -0.0089, Test_r2: -0.002903
# Epoch [173/300], Train Loss: 4.1928, Test Loss: 4.1583, Train_r2: -0.0123, Test_r2: -0.020900
# Epoch [174/300], Train Loss: 4.1924, Test Loss: 4.1582, Train_r2: -0.0046, Test_r2: -0.000752
# Epoch [175/300], Train Loss: 4.1921, Test Loss: 4.1585, Train_r2: -0.0080, Test_r2: -0.005715
# Epoch [176/300], Train Loss: 4.1922, Test Loss: 4.1590, Train_r2: -0.0059, Test_r2: -0.012903
# Epoch [177/300], Train Loss: 4.1925, Test Loss: 4.1581, Train_r2: -0.0041, Test_r2: -0.006659
# Epoch [178/300], Train Loss: 4.1926, Test Loss: 4.1581, Train_r2: -0.0040, Test_r2: -0.008088
# Epoch [179/300], Train Loss: 4.1933, Test Loss: 4.1593, Train_r2: -0.0139, Test_r2: -0.002579
# Epoch [180/300], Train Loss: 4.1927, Test Loss: 4.1587, Train_r2: -0.0061, Test_r2: -0.005071
# Epoch [181/300], Train Loss: 4.1946, Test Loss: 4.1569, Train_r2: -0.0102, Test_r2: -0.006621
# Epoch [182/300], Train Loss: 4.1932, Test Loss: 4.1579, Train_r2: -0.0097, Test_r2: -0.004185
# Epoch [183/300], Train Loss: 4.1920, Test Loss: 4.1589, Train_r2: -0.0040, Test_r2: -0.004177
# Epoch [184/300], Train Loss: 4.1925, Test Loss: 4.1586, Train_r2: -0.0100, Test_r2: -0.004860
# Epoch [185/300], Train Loss: 4.1921, Test Loss: 4.1581, Train_r2: -0.0064, Test_r2: -0.013259
# Epoch [186/300], Train Loss: 4.1928, Test Loss: 4.1574, Train_r2: -0.0104, Test_r2: -0.002131
# Epoch [187/300], Train Loss: 4.1922, Test Loss: 4.1582, Train_r2: -0.0057, Test_r2: -0.002309
# Epoch [188/300], Train Loss: 4.1935, Test Loss: 4.1597, Train_r2: -0.0143, Test_r2: -0.009829
# Epoch [189/300], Train Loss: 4.1936, Test Loss: 4.1577, Train_r2: -0.0073, Test_r2: -0.003775
# Epoch [190/300], Train Loss: 4.1923, Test Loss: 4.1582, Train_r2: -0.0108, Test_r2: -0.007502
# Epoch [191/300], Train Loss: 4.1925, Test Loss: 4.1577, Train_r2: -0.0074, Test_r2: -0.011176
# Epoch [192/300], Train Loss: 4.1926, Test Loss: 4.1575, Train_r2: -0.0081, Test_r2: -0.007673
# Epoch [193/300], Train Loss: 4.1928, Test Loss: 4.1594, Train_r2: -0.0110, Test_r2: -0.001458
# Epoch [194/300], Train Loss: 4.1923, Test Loss: 4.1582, Train_r2: -0.0077, Test_r2: -0.009340
# Epoch [195/300], Train Loss: 4.1921, Test Loss: 4.1578, Train_r2: -0.0094, Test_r2: -0.002713
# Epoch [196/300], Train Loss: 4.1924, Test Loss: 4.1577, Train_r2: -0.0081, Test_r2: -0.000817
# Epoch [197/300], Train Loss: 4.1920, Test Loss: 4.1589, Train_r2: -0.0058, Test_r2: -0.001441
# Epoch [198/300], Train Loss: 4.1923, Test Loss: 4.1592, Train_r2: -0.0101, Test_r2: -0.003677
# Epoch [199/300], Train Loss: 4.1920, Test Loss: 4.1580, Train_r2: -0.0073, Test_r2: -0.009256
# Epoch [200/300], Train Loss: 4.1919, Test Loss: 4.1582, Train_r2: -0.0031, Test_r2: -0.010694
# Epoch [201/300], Train Loss: 4.1921, Test Loss: 4.1582, Train_r2: -0.0046, Test_r2: -0.002072
# Epoch [202/300], Train Loss: 4.1928, Test Loss: 4.1581, Train_r2: -0.0108, Test_r2: -0.013072
# Epoch [203/300], Train Loss: 4.1924, Test Loss: 4.1590, Train_r2: -0.0089, Test_r2: -0.017378
# Epoch [204/300], Train Loss: 4.1926, Test Loss: 4.1570, Train_r2: -0.0063, Test_r2: -0.003929
# Epoch [205/300], Train Loss: 4.1917, Test Loss: 4.1577, Train_r2: -0.0040, Test_r2: -0.004077
# Epoch [206/300], Train Loss: 4.1919, Test Loss: 4.1574, Train_r2: -0.0075, Test_r2: -0.000737
# Epoch [207/300], Train Loss: 4.1912, Test Loss: 4.1564, Train_r2: -0.0097, Test_r2: -0.005404
# Epoch [208/300], Train Loss: 4.1900, Test Loss: 4.1562, Train_r2: -0.0073, Test_r2: -0.001637
# Epoch [209/300], Train Loss: 4.1865, Test Loss: 4.1466, Train_r2: -0.0083, Test_r2: 0.001943
# Epoch [210/300], Train Loss: 4.1682, Test Loss: 4.0775, Train_r2: -0.0002, Test_r2: 0.009944
# Epoch [211/300], Train Loss: 3.9443, Test Loss: 3.6634, Train_r2: 0.0525, Test_r2: 0.111338
# Epoch [212/300], Train Loss: 3.6602, Test Loss: 3.7471, Train_r2: 0.1223, Test_r2: 0.096868
# Epoch [213/300], Train Loss: 3.6155, Test Loss: 3.4789, Train_r2: 0.1317, Test_r2: 0.160038
# Epoch [214/300], Train Loss: 3.3965, Test Loss: 3.3641, Train_r2: 0.1855, Test_r2: 0.188336
# Epoch [215/300], Train Loss: 3.3131, Test Loss: 3.2533, Train_r2: 0.2005, Test_r2: 0.200524
# Epoch [216/300], Train Loss: 3.1153, Test Loss: 3.1143, Train_r2: 0.2513, Test_r2: 0.251484
# Epoch [217/300], Train Loss: 2.9467, Test Loss: 2.9672, Train_r2: 0.2896, Test_r2: 0.284104
# Epoch [218/300], Train Loss: 2.8444, Test Loss: 2.7931, Train_r2: 0.3147, Test_r2: 0.323803
# Epoch [219/300], Train Loss: 2.6232, Test Loss: 2.5712, Train_r2: 0.3595, Test_r2: 0.378272
# Epoch [220/300], Train Loss: 2.4059, Test Loss: 2.3653, Train_r2: 0.4210, Test_r2: 0.427296
# Epoch [221/300], Train Loss: 2.2349, Test Loss: 2.1048, Train_r2: 0.4586, Test_r2: 0.489971
# Epoch [222/300], Train Loss: 2.0929, Test Loss: 1.9375, Train_r2: 0.4957, Test_r2: 0.532515
# Epoch [223/300], Train Loss: 1.9389, Test Loss: 1.7423, Train_r2: 0.5309, Test_r2: 0.579850
# Epoch [224/300], Train Loss: 1.7723, Test Loss: 1.7206, Train_r2: 0.5744, Test_r2: 0.584253
# Epoch [225/300], Train Loss: 1.6221, Test Loss: 1.4320, Train_r2: 0.6076, Test_r2: 0.651627
# Epoch [226/300], Train Loss: 1.4472, Test Loss: 1.2980, Train_r2: 0.6516, Test_r2: 0.683824
# Epoch [227/300], Train Loss: 1.3184, Test Loss: 1.1386, Train_r2: 0.6825, Test_r2: 0.724897
# Epoch [228/300], Train Loss: 1.2279, Test Loss: 1.1004, Train_r2: 0.7025, Test_r2: 0.732861
# Epoch [229/300], Train Loss: 1.0360, Test Loss: 0.9759, Train_r2: 0.7499, Test_r2: 0.762631
# Epoch [230/300], Train Loss: 0.9278, Test Loss: 0.8834, Train_r2: 0.7776, Test_r2: 0.784917
# Epoch [231/300], Train Loss: 0.8481, Test Loss: 0.6891, Train_r2: 0.7967, Test_r2: 0.833087
# Epoch [232/300], Train Loss: 0.6651, Test Loss: 0.6233, Train_r2: 0.8404, Test_r2: 0.849177
# Epoch [233/300], Train Loss: 0.5867, Test Loss: 0.6372, Train_r2: 0.8606, Test_r2: 0.844077
# Epoch [234/300], Train Loss: 0.5109, Test Loss: 0.4560, Train_r2: 0.8782, Test_r2: 0.889681
# Epoch [235/300], Train Loss: 0.4323, Test Loss: 0.4090, Train_r2: 0.8956, Test_r2: 0.900918
# Epoch [236/300], Train Loss: 0.3819, Test Loss: 0.3727, Train_r2: 0.9082, Test_r2: 0.910049
# Epoch [237/300], Train Loss: 0.3606, Test Loss: 0.3408, Train_r2: 0.9131, Test_r2: 0.921750
# Epoch [238/300], Train Loss: 0.3424, Test Loss: 0.3277, Train_r2: 0.9179, Test_r2: 0.920855
# Epoch [239/300], Train Loss: 0.3034, Test Loss: 0.2910, Train_r2: 0.9272, Test_r2: 0.928627
# Epoch [240/300], Train Loss: 0.2738, Test Loss: 0.2617, Train_r2: 0.9350, Test_r2: 0.937675
# Epoch [241/300], Train Loss: 0.2460, Test Loss: 0.2418, Train_r2: 0.9409, Test_r2: 0.940917
# Epoch [242/300], Train Loss: 0.2394, Test Loss: 0.2321, Train_r2: 0.9429, Test_r2: 0.944285
# Epoch [243/300], Train Loss: 0.2163, Test Loss: 0.2205, Train_r2: 0.9477, Test_r2: 0.947223
# Epoch [244/300], Train Loss: 0.2034, Test Loss: 0.2101, Train_r2: 0.9517, Test_r2: 0.949759
# Epoch [245/300], Train Loss: 0.1872, Test Loss: 0.2137, Train_r2: 0.9554, Test_r2: 0.947876
# Epoch [246/300], Train Loss: 0.2013, Test Loss: 0.2178, Train_r2: 0.9527, Test_r2: 0.946512
# Epoch [247/300], Train Loss: 0.1850, Test Loss: 0.1749, Train_r2: 0.9563, Test_r2: 0.955692
# Epoch [248/300], Train Loss: 0.1621, Test Loss: 0.1617, Train_r2: 0.9614, Test_r2: 0.960649
# Epoch [249/300], Train Loss: 0.1698, Test Loss: 0.1653, Train_r2: 0.9593, Test_r2: 0.959505
# Epoch [250/300], Train Loss: 0.1463, Test Loss: 0.1489, Train_r2: 0.9647, Test_r2: 0.964298
# Epoch [251/300], Train Loss: 0.1470, Test Loss: 0.1890, Train_r2: 0.9649, Test_r2: 0.954003
# Epoch [252/300], Train Loss: 0.1422, Test Loss: 0.1362, Train_r2: 0.9668, Test_r2: 0.967313
# Epoch [253/300], Train Loss: 0.1459, Test Loss: 0.1851, Train_r2: 0.9648, Test_r2: 0.955326
# Epoch [254/300], Train Loss: 0.1407, Test Loss: 0.1298, Train_r2: 0.9666, Test_r2: 0.968052
# Epoch [255/300], Train Loss: 0.1161, Test Loss: 0.1199, Train_r2: 0.9725, Test_r2: 0.971246
# Epoch [256/300], Train Loss: 0.1113, Test Loss: 0.1196, Train_r2: 0.9738, Test_r2: 0.970715
# Epoch [257/300], Train Loss: 0.1074, Test Loss: 0.1096, Train_r2: 0.9744, Test_r2: 0.973468
# Epoch [258/300], Train Loss: 0.0998, Test Loss: 0.1112, Train_r2: 0.9762, Test_r2: 0.973333
# Epoch [259/300], Train Loss: 0.1063, Test Loss: 0.1312, Train_r2: 0.9743, Test_r2: 0.967924
# Epoch [260/300], Train Loss: 0.1003, Test Loss: 0.1139, Train_r2: 0.9759, Test_r2: 0.972337
# Epoch [261/300], Train Loss: 0.0949, Test Loss: 0.1129, Train_r2: 0.9772, Test_r2: 0.973042
# Epoch [262/300], Train Loss: 0.0956, Test Loss: 0.0946, Train_r2: 0.9770, Test_r2: 0.977534
# Epoch [263/300], Train Loss: 0.0878, Test Loss: 0.0920, Train_r2: 0.9788, Test_r2: 0.977554
# Epoch [264/300], Train Loss: 0.0835, Test Loss: 0.0913, Train_r2: 0.9801, Test_r2: 0.978267
# Epoch [265/300], Train Loss: 0.0775, Test Loss: 0.0862, Train_r2: 0.9814, Test_r2: 0.979176
# Epoch [266/300], Train Loss: 0.0760, Test Loss: 0.0809, Train_r2: 0.9818, Test_r2: 0.980923
# Epoch [267/300], Train Loss: 0.0772, Test Loss: 0.1154, Train_r2: 0.9816, Test_r2: 0.971516
# Epoch [268/300], Train Loss: 0.0838, Test Loss: 0.0775, Train_r2: 0.9801, Test_r2: 0.981453
# Epoch [269/300], Train Loss: 0.0708, Test Loss: 0.0761, Train_r2: 0.9831, Test_r2: 0.981751
# Epoch [270/300], Train Loss: 0.0712, Test Loss: 0.0774, Train_r2: 0.9831, Test_r2: 0.981751
# Epoch [271/300], Train Loss: 0.0675, Test Loss: 0.0916, Train_r2: 0.9838, Test_r2: 0.977968
# Epoch [272/300], Train Loss: 0.0734, Test Loss: 0.0734, Train_r2: 0.9828, Test_r2: 0.982599
# Epoch [273/300], Train Loss: 0.0656, Test Loss: 0.0718, Train_r2: 0.9846, Test_r2: 0.982969
# Epoch [274/300], Train Loss: 0.0613, Test Loss: 0.0662, Train_r2: 0.9852, Test_r2: 0.983891
# Epoch [275/300], Train Loss: 0.0638, Test Loss: 0.0737, Train_r2: 0.9848, Test_r2: 0.982417
# Epoch [276/300], Train Loss: 0.0589, Test Loss: 0.0639, Train_r2: 0.9858, Test_r2: 0.984659
# Epoch [277/300], Train Loss: 0.0575, Test Loss: 0.0670, Train_r2: 0.9862, Test_r2: 0.983969
# Epoch [278/300], Train Loss: 0.0574, Test Loss: 0.0628, Train_r2: 0.9863, Test_r2: 0.984904
# Epoch [279/300], Train Loss: 0.0564, Test Loss: 0.0642, Train_r2: 0.9863, Test_r2: 0.984815
# Epoch [280/300], Train Loss: 0.0537, Test Loss: 0.0598, Train_r2: 0.9872, Test_r2: 0.985437
# Epoch [281/300], Train Loss: 0.0540, Test Loss: 0.0608, Train_r2: 0.9873, Test_r2: 0.985622
# Epoch [282/300], Train Loss: 0.0524, Test Loss: 0.0670, Train_r2: 0.9874, Test_r2: 0.983690
# Epoch [283/300], Train Loss: 0.0538, Test Loss: 0.0727, Train_r2: 0.9872, Test_r2: 0.982256
# Epoch [284/300], Train Loss: 0.0613, Test Loss: 0.0641, Train_r2: 0.9856, Test_r2: 0.984440
# Epoch [285/300], Train Loss: 0.0604, Test Loss: 0.0592, Train_r2: 0.9860, Test_r2: 0.985813
# Epoch [286/300], Train Loss: 0.0459, Test Loss: 0.0509, Train_r2: 0.9892, Test_r2: 0.988057
# Epoch [287/300], Train Loss: 0.0481, Test Loss: 0.0547, Train_r2: 0.9887, Test_r2: 0.986808
# Epoch [288/300], Train Loss: 0.0489, Test Loss: 0.0511, Train_r2: 0.9883, Test_r2: 0.987599
# Epoch [289/300], Train Loss: 0.0481, Test Loss: 0.0555, Train_r2: 0.9885, Test_r2: 0.986503
# Epoch [290/300], Train Loss: 0.0441, Test Loss: 0.0478, Train_r2: 0.9893, Test_r2: 0.988436
# Epoch [291/300], Train Loss: 0.0418, Test Loss: 0.0457, Train_r2: 0.9899, Test_r2: 0.989173
# Epoch [292/300], Train Loss: 0.0419, Test Loss: 0.0450, Train_r2: 0.9898, Test_r2: 0.989420
# Epoch [293/300], Train Loss: 0.0425, Test Loss: 0.0603, Train_r2: 0.9898, Test_r2: 0.985395
# Epoch [294/300], Train Loss: 0.0440, Test Loss: 0.0459, Train_r2: 0.9895, Test_r2: 0.988943
# Epoch [295/300], Train Loss: 0.0379, Test Loss: 0.0425, Train_r2: 0.9910, Test_r2: 0.989476
# Epoch [296/300], Train Loss: 0.0369, Test Loss: 0.0406, Train_r2: 0.9912, Test_r2: 0.990382
# Epoch [297/300], Train Loss: 0.0360, Test Loss: 0.0443, Train_r2: 0.9914, Test_r2: 0.989533
# Epoch [298/300], Train Loss: 0.0347, Test Loss: 0.0392, Train_r2: 0.9917, Test_r2: 0.990605
# Epoch [299/300], Train Loss: 0.0399, Test Loss: 0.0631, Train_r2: 0.9903, Test_r2: 0.984704
# Epoch [300/300], Train Loss: 0.0377, Test Loss: 0.0394, Train_r2: 0.9912, Test_r2: 0.990459

# %%
plt.style.use('dark_background')
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

axs[0].plot(train_losses, '-o', color='magenta', label='Train Losses')
axs[0].plot(test_losses, '-o', color='orange', label='Test Losses')
axs[0].set_title("Train vs Test Losses")
axs[0].set_ylabel("MSELosses averaged across batches")
axs[0].set_xlabel("Epochs")
axs[0].text(160, 27, f"Final: {train_losses[-1]:.4f}, {test_losses[-1]:.4f}")
axs[0].grid(alpha=0.2)
axs[0].legend()

axs[1].plot(train_r2, '-o', color='magenta', label='Train R2')
axs[1].plot(test_r2, '-o', color='orange', label='Test R2')
axs[1].set_title("Train vs Test R2")
axs[1].set_ylabel("R2 score averaged across batches")
axs[1].set_xlabel("Epochs")
axs[1].grid(alpha=0.2)
axs[1].text(160, -0.75, f"Final: {train_r2[-1]:.4f}, {test_r2[-1]:.4f}")
axs[1].legend()
plt.show()

# %%
torch.save(model.state_dict(), "D:/Assignments/Autonomize/model_v1.pt")

# %%
# Sample DNA sequence
sample = 'NGTCNNCCAGTTTGAACNGTAACGACGTACATCGACGNCGGNNNTNCAGGTGCNCTGAANNCAACCTGCNCANCGGTTGNCTCANCATANAANGCNCCANAATGATGTNTNNTATCTGCATCCNCNNA'

alphabet = 'NACGT'
dna2int = {a: i for i, a in enumerate(alphabet)}
intseq_to_dnaseq = partial(map, dna2int.get)
input_sequence_int = list(intseq_to_dnaseq(sample))

# Perform inference
with torch.no_grad():
    input_tensor = torch.tensor(input_sequence_int).long().unsqueeze(0)  # Add batch dimension
    output = model(input_tensor)

# %%
output
# Out:
# tensor([[6.0275]])

# %% [markdown]
# # Part 2: what if the DNA sequences are not the same length

# %% [markdown]
# ### Approach 1:
# Passing the padded sequences directly to the model without `pack_padded_sequence` and `pad_packed_sequence` operations in the forward method of the model architecture.

# %%
# hint we will need following imports
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence

# %%
# DO NOT CHANGE HERE
random.seed(13)

# Use this for getting x label
def rand_sequence_var_len(n_seqs: int, lb: int=16, ub: int=128) -> Sequence[int]:
    for i in range(n_seqs):
        seq_len = random.randint(lb, ub)
        yield [random.randint(1, 5) for _ in range(seq_len)]


# Use this for getting y label
def count_cpgs(seq: str) -> int:
    cgs = 0
    for i in range(0, len(seq) - 1):
        dimer = seq[i:i+2]
        # note that seq is a string, not a list
        if dimer == "CG":
            cgs += 1
    return cgs


# Alphabet helpers   
alphabet = 'NACGT'
dna2int = {a: i for a, i in zip(alphabet, range(1, 6))}
int2dna = {i: a for a, i in zip(alphabet, range(1, 6))}
dna2int.update({"pad": 0})
int2dna.update({0: "<pad>"})

intseq_to_dnaseq = partial(map, int2dna.get)
dnaseq_to_intseq = partial(map, dna2int.get)

# %%
# TODO complete the task based on the change
def prepare_data(num_samples=100, min_len=16, max_len=128):
    # TODO prepared the training and test data
    # you need to call rand_sequence and count_cpgs here to create the dataset
    #step 1
    X_dna_seqs_train = list(rand_sequence_var_len(num_samples, min_len, max_len))
    #step 2
    temp = list(map(intseq_to_dnaseq, X_dna_seqs_train))
    dna_seqs = [''.join(seq) for seq in temp]
    #step3
    y_dna_seqs = [count_cpgs(seq) for seq in dna_seqs]
    
    return X_dna_seqs_train, y_dna_seqs
    
    
min_len, max_len = 64, 128
train_x, train_y = prepare_data(2048, min_len, max_len)
test_x, test_y = prepare_data(512, min_len, max_len)

# %%
print(len(train_x), len(train_y), len(test_x), len(test_y))
# Out:
# 2048 2048 512 512

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, lists, labels) -> None:
        self.lists = lists
        self.labels = labels

    def __getitem__(self, index):
        # Convert sequences to LongTensor
        sequences_tensor = torch.LongTensor(self.lists[index])

        # Convert labels to FloatTensor with unsqueeze to make it 2D
        label_tensor = torch.tensor(self.labels[index], dtype=torch.float32)

        return sequences_tensor, label_tensor

    def __len__(self):
        return len(self.lists)

    
# this will be a collate_fn for dataloader to pad sequence  
class PadSequence:
    def __init__(self, padding_value=0) -> None:
        self.padding_value = padding_value

    def __call__(self, batch):
        # Sort the batch by sequence length in descending order
        batch = sorted(batch, key=lambda x: len(x[0]), reverse=True)
        # Get the sequence and labels from the sorted batch
        sequences, labels = zip(*batch)
        # Pad the sequence
        padded_sequences = pad_sequence(sequences, batch_first=True, padding_value=self.padding_value)

        return padded_sequences, torch.tensor(labels)

# %%
# some config
LSTM_HIDDEN = 16
LSTM_LAYER = 3
BATCH_SIZE = 128
LEARNING_RATE = 0.001
NUM_EPOCHS = 300
VOCAB_SIZE = 6
OUTPUT_SIZE = 1

# %%
train_dataset = MyDataset(train_x, train_y)
test_dataset = MyDataset(test_x, test_y)

pad_sequence_collate_fn = PadSequence(padding_value=dna2int['pad'])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, collate_fn=pad_sequence_collate_fn, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, collate_fn=pad_sequence_collate_fn, shuffle=True)

# %%
# TODO complete the rest
# init model / loss function / optimizer etc.
model = CpGPredictor(vocab_size=VOCAB_SIZE, embedding_dim=16, hidden_size=LSTM_HIDDEN, num_layers=LSTM_LAYER, output_size=OUTPUT_SIZE)
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
# training (you can modify the code below)

# Initialize Losses
train_losses = []
test_losses = []

train_r2 = []
test_r2 = []

for epoch in range(NUM_EPOCHS):
    
    # Set the model on training mode.
    model.train()

    # Initialize batch losses
    train_batch_losses = []
    test_batch_losses = []

    train_batch_r2 = []
    test_batch_r2 = []
    
    for X, y in train_loader:
        #TODO complete training loop

        # Initialize hidden state
        hc = model.init_hidden(X.size(0))

        y_hat = model(X, hc)

        # Compute Loss
        loss = loss_fn(y_hat, y.unsqueeze(1))

        # Compute r2
        r2 = r2_score(y.detach().numpy(), y_hat.detach().numpy())

        # Backprop and Optimzation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Store the batch loss
        train_batch_losses.append(loss.item())
        train_batch_r2.append(r2)
    
    # Average the batch losses and store as a global loss
    train_losses.append(np.mean(train_batch_losses))
    train_r2.append(np.mean(train_batch_r2))

    # Set the model on evaluation mode.
    model.eval()
    for X, y in test_loader:
        with torch.no_grad():
            # Initialize hidden state
            hc = model.init_hidden(X.size(0))

            y_hat = model(X, hc)
            loss = loss_fn(y_hat, y.unsqueeze(1))
            r2 = r2_score(y.detach().numpy(), y_hat.detach().numpy())

            test_batch_losses.append(loss.item())
            test_batch_r2.append(r2)

    # Average loss across the batches
    test_losses.append(np.mean(test_batch_losses))
    test_r2.append(np.mean(test_batch_r2))
    
    print(f'Epoch [{epoch + 1}/{NUM_EPOCHS}], Train Loss: {train_losses[-1]:.4f}, Test Loss: {test_losses[-1]:.4f}, Train_r2: {train_r2[-1]:.4f}, Test_r2: {test_r2[-1]:4f}')
# Out:
# Epoch [1/300], Train Loss: 18.2051, Test Loss: 17.4544, Train_r2: -4.0676, Test_r2: -3.527506
# Epoch [2/300], Train Loss: 15.5200, Test Loss: 13.7226, Train_r2: -3.3272, Test_r2: -2.566305
# Epoch [3/300], Train Loss: 11.0883, Test Loss: 9.0917, Train_r2: -2.0522, Test_r2: -1.329267
# Epoch [4/300], Train Loss: 7.4324, Test Loss: 6.5074, Train_r2: -1.0528, Test_r2: -0.692678
# Epoch [5/300], Train Loss: 5.4885, Test Loss: 5.1616, Train_r2: -0.5292, Test_r2: -0.324075
# Epoch [6/300], Train Loss: 4.5051, Test Loss: 4.4947, Train_r2: -0.2488, Test_r2: -0.154961
# Epoch [7/300], Train Loss: 4.0314, Test Loss: 4.1667, Train_r2: -0.1183, Test_r2: -0.066034
# Epoch [8/300], Train Loss: 3.7999, Test Loss: 4.0164, Train_r2: -0.0493, Test_r2: -0.038736
# Epoch [9/300], Train Loss: 3.7047, Test Loss: 3.9512, Train_r2: -0.0235, Test_r2: -0.018873
# Epoch [10/300], Train Loss: 3.6642, Test Loss: 3.9281, Train_r2: -0.0098, Test_r2: -0.006615
# Epoch [11/300], Train Loss: 3.6500, Test Loss: 3.9196, Train_r2: -0.0074, Test_r2: -0.001719
# Epoch [12/300], Train Loss: 3.6454, Test Loss: 3.9164, Train_r2: -0.0144, Test_r2: -0.005112
# Epoch [13/300], Train Loss: 3.6436, Test Loss: 3.9155, Train_r2: -0.0042, Test_r2: -0.012884
# Epoch [14/300], Train Loss: 3.6433, Test Loss: 3.9149, Train_r2: -0.0036, Test_r2: -0.007993
# Epoch [15/300], Train Loss: 3.6433, Test Loss: 3.9147, Train_r2: -0.0106, Test_r2: -0.003029
# Epoch [16/300], Train Loss: 3.6431, Test Loss: 3.9147, Train_r2: -0.0056, Test_r2: -0.003977
# Epoch [17/300], Train Loss: 3.6431, Test Loss: 3.9147, Train_r2: -0.0054, Test_r2: -0.002100
# Epoch [18/300], Train Loss: 3.6433, Test Loss: 3.9148, Train_r2: -0.0057, Test_r2: -0.002263
# Epoch [19/300], Train Loss: 3.6433, Test Loss: 3.9148, Train_r2: -0.0142, Test_r2: -0.002949
# Epoch [20/300], Train Loss: 3.6452, Test Loss: 3.9145, Train_r2: -0.0114, Test_r2: -0.004400
# Epoch [21/300], Train Loss: 3.6434, Test Loss: 3.9147, Train_r2: -0.0081, Test_r2: -0.007474
# Epoch [22/300], Train Loss: 3.6433, Test Loss: 3.9147, Train_r2: -0.0075, Test_r2: -0.008033
# Epoch [23/300], Train Loss: 3.6435, Test Loss: 3.9148, Train_r2: -0.0128, Test_r2: -0.009433
# Epoch [24/300], Train Loss: 3.6438, Test Loss: 3.9147, Train_r2: -0.0117, Test_r2: -0.001508
# Epoch [25/300], Train Loss: 3.6431, Test Loss: 3.9146, Train_r2: -0.0025, Test_r2: -0.004947
# Epoch [26/300], Train Loss: 3.6438, Test Loss: 3.9145, Train_r2: -0.0111, Test_r2: -0.013663
# Epoch [27/300], Train Loss: 3.6433, Test Loss: 3.9145, Train_r2: -0.0054, Test_r2: -0.006091
# Epoch [28/300], Train Loss: 3.6435, Test Loss: 3.9147, Train_r2: -0.0121, Test_r2: -0.004958
# Epoch [29/300], Train Loss: 3.6434, Test Loss: 3.9148, Train_r2: -0.0070, Test_r2: -0.003053
# Epoch [30/300], Train Loss: 3.6433, Test Loss: 3.9145, Train_r2: -0.0078, Test_r2: -0.002735
# Epoch [31/300], Train Loss: 3.6434, Test Loss: 3.9145, Train_r2: -0.0124, Test_r2: -0.007860
# Epoch [32/300], Train Loss: 3.6432, Test Loss: 3.9146, Train_r2: -0.0097, Test_r2: -0.013206
# Epoch [33/300], Train Loss: 3.6431, Test Loss: 3.9145, Train_r2: -0.0048, Test_r2: -0.009768
# Epoch [34/300], Train Loss: 3.6434, Test Loss: 3.9145, Train_r2: -0.0062, Test_r2: -0.013062
# Epoch [35/300], Train Loss: 3.6438, Test Loss: 3.9148, Train_r2: -0.0054, Test_r2: -0.002548
# Epoch [36/300], Train Loss: 3.6430, Test Loss: 3.9146, Train_r2: -0.0053, Test_r2: -0.026344
# Epoch [37/300], Train Loss: 3.6432, Test Loss: 3.9144, Train_r2: -0.0057, Test_r2: -0.004400
# Epoch [38/300], Train Loss: 3.6430, Test Loss: 3.9144, Train_r2: -0.0072, Test_r2: -0.008257
# Epoch [39/300], Train Loss: 3.6433, Test Loss: 3.9147, Train_r2: -0.0060, Test_r2: -0.004684
# Epoch [40/300], Train Loss: 3.6431, Test Loss: 3.9147, Train_r2: -0.0036, Test_r2: -0.010874
# Epoch [41/300], Train Loss: 3.6430, Test Loss: 3.9146, Train_r2: -0.0031, Test_r2: -0.031545
# Epoch [42/300], Train Loss: 3.6431, Test Loss: 3.9145, Train_r2: -0.0086, Test_r2: -0.000795
# Epoch [43/300], Train Loss: 3.6432, Test Loss: 3.9145, Train_r2: -0.0049, Test_r2: -0.003145
# Epoch [44/300], Train Loss: 3.6434, Test Loss: 3.9144, Train_r2: -0.0067, Test_r2: -0.002760
# Epoch [45/300], Train Loss: 3.6433, Test Loss: 3.9146, Train_r2: -0.0083, Test_r2: -0.015413
# Epoch [46/300], Train Loss: 3.6433, Test Loss: 3.9144, Train_r2: -0.0079, Test_r2: -0.010968
# Epoch [47/300], Train Loss: 3.6432, Test Loss: 3.9144, Train_r2: -0.0078, Test_r2: -0.013009
# Epoch [48/300], Train Loss: 3.6434, Test Loss: 3.9144, Train_r2: -0.0084, Test_r2: -0.006693
# Epoch [49/300], Train Loss: 3.6429, Test Loss: 3.9146, Train_r2: -0.0090, Test_r2: -0.019166
# Epoch [50/300], Train Loss: 3.6438, Test Loss: 3.9144, Train_r2: -0.0084, Test_r2: -0.009049
# Epoch [51/300], Train Loss: 3.6448, Test Loss: 3.9152, Train_r2: -0.0055, Test_r2: -0.006457
# Epoch [52/300], Train Loss: 3.6433, Test Loss: 3.9145, Train_r2: -0.0056, Test_r2: -0.005705
# Epoch [53/300], Train Loss: 3.6431, Test Loss: 3.9144, Train_r2: -0.0125, Test_r2: -0.003763
# Epoch [54/300], Train Loss: 3.6433, Test Loss: 3.9143, Train_r2: -0.0058, Test_r2: -0.010873
# Epoch [55/300], Train Loss: 3.6432, Test Loss: 3.9146, Train_r2: -0.0036, Test_r2: -0.003580
# Epoch [56/300], Train Loss: 3.6433, Test Loss: 3.9144, Train_r2: -0.0074, Test_r2: -0.001900
# Epoch [57/300], Train Loss: 3.6430, Test Loss: 3.9145, Train_r2: -0.0030, Test_r2: -0.008746
# Epoch [58/300], Train Loss: 3.6433, Test Loss: 3.9145, Train_r2: -0.0086, Test_r2: -0.003710
# Epoch [59/300], Train Loss: 3.6429, Test Loss: 3.9144, Train_r2: -0.0061, Test_r2: -0.006363
# Epoch [60/300], Train Loss: 3.6432, Test Loss: 3.9145, Train_r2: -0.0069, Test_r2: -0.005442
# Epoch [61/300], Train Loss: 3.6437, Test Loss: 3.9143, Train_r2: -0.0114, Test_r2: -0.007100
# Epoch [62/300], Train Loss: 3.6432, Test Loss: 3.9145, Train_r2: -0.0055, Test_r2: -0.006915
# Epoch [63/300], Train Loss: 3.6435, Test Loss: 3.9144, Train_r2: -0.0082, Test_r2: -0.002242
# Epoch [64/300], Train Loss: 3.6446, Test Loss: 3.9144, Train_r2: -0.0118, Test_r2: -0.006313
# Epoch [65/300], Train Loss: 3.6434, Test Loss: 3.9150, Train_r2: -0.0071, Test_r2: -0.008977
# Epoch [66/300], Train Loss: 3.6446, Test Loss: 3.9143, Train_r2: -0.0070, Test_r2: -0.002727
# Epoch [67/300], Train Loss: 3.6427, Test Loss: 3.9144, Train_r2: -0.0078, Test_r2: -0.005260
# Epoch [68/300], Train Loss: 3.6435, Test Loss: 3.9151, Train_r2: -0.0086, Test_r2: -0.002597
# Epoch [69/300], Train Loss: 3.6440, Test Loss: 3.9143, Train_r2: -0.0074, Test_r2: -0.008964
# Epoch [70/300], Train Loss: 3.6431, Test Loss: 3.9143, Train_r2: -0.0066, Test_r2: -0.002722
# Epoch [71/300], Train Loss: 3.6437, Test Loss: 3.9147, Train_r2: -0.0055, Test_r2: -0.005979
# Epoch [72/300], Train Loss: 3.6430, Test Loss: 3.9144, Train_r2: -0.0043, Test_r2: -0.004741
# Epoch [73/300], Train Loss: 3.6430, Test Loss: 3.9144, Train_r2: -0.0047, Test_r2: -0.008868
# Epoch [74/300], Train Loss: 3.6436, Test Loss: 3.9142, Train_r2: -0.0121, Test_r2: -0.005389
# Epoch [75/300], Train Loss: 3.6434, Test Loss: 3.9141, Train_r2: -0.0057, Test_r2: -0.001560
# Epoch [76/300], Train Loss: 3.6427, Test Loss: 3.9147, Train_r2: -0.0034, Test_r2: -0.001142
# Epoch [77/300], Train Loss: 3.6430, Test Loss: 3.9145, Train_r2: -0.0041, Test_r2: -0.011480
# Epoch [78/300], Train Loss: 3.6444, Test Loss: 3.9145, Train_r2: -0.0166, Test_r2: -0.008617
# Epoch [79/300], Train Loss: 3.6429, Test Loss: 3.9139, Train_r2: -0.0080, Test_r2: -0.001884
# Epoch [80/300], Train Loss: 3.6434, Test Loss: 3.9135, Train_r2: -0.0053, Test_r2: -0.000615
# Epoch [81/300], Train Loss: 3.6434, Test Loss: 3.9133, Train_r2: -0.0056, Test_r2: -0.007439
# Epoch [82/300], Train Loss: 3.6436, Test Loss: 3.9129, Train_r2: -0.0110, Test_r2: -0.005213
# Epoch [83/300], Train Loss: 3.6422, Test Loss: 3.9122, Train_r2: -0.0139, Test_r2: -0.015354
# Epoch [84/300], Train Loss: 3.6409, Test Loss: 3.9111, Train_r2: -0.0066, Test_r2: -0.003512
# Epoch [85/300], Train Loss: 3.6396, Test Loss: 3.9066, Train_r2: -0.0097, Test_r2: -0.005348
# Epoch [86/300], Train Loss: 3.6331, Test Loss: 3.8978, Train_r2: -0.0055, Test_r2: 0.002454
# Epoch [87/300], Train Loss: 3.6190, Test Loss: 3.8705, Train_r2: 0.0016, Test_r2: -0.002498
# Epoch [88/300], Train Loss: 3.5764, Test Loss: 3.7948, Train_r2: 0.0100, Test_r2: 0.026667
# Epoch [89/300], Train Loss: 3.5629, Test Loss: 3.7443, Train_r2: 0.0179, Test_r2: 0.035318
# Epoch [90/300], Train Loss: 3.4198, Test Loss: 3.4749, Train_r2: 0.0569, Test_r2: 0.108672
# Epoch [91/300], Train Loss: 3.1992, Test Loss: 3.2701, Train_r2: 0.1157, Test_r2: 0.160363
# Epoch [92/300], Train Loss: 3.0982, Test Loss: 3.1645, Train_r2: 0.1392, Test_r2: 0.187604
# Epoch [93/300], Train Loss: 2.9583, Test Loss: 2.9748, Train_r2: 0.1837, Test_r2: 0.238962
# Epoch [94/300], Train Loss: 2.8499, Test Loss: 2.8653, Train_r2: 0.2107, Test_r2: 0.262269
# Epoch [95/300], Train Loss: 2.8442, Test Loss: 2.8561, Train_r2: 0.2104, Test_r2: 0.261679
# Epoch [96/300], Train Loss: 2.7754, Test Loss: 2.7549, Train_r2: 0.2286, Test_r2: 0.291933
# Epoch [97/300], Train Loss: 2.7476, Test Loss: 2.7667, Train_r2: 0.2404, Test_r2: 0.281646
# Epoch [98/300], Train Loss: 2.6374, Test Loss: 2.6330, Train_r2: 0.2712, Test_r2: 0.324504
# Epoch [99/300], Train Loss: 2.5388, Test Loss: 2.5816, Train_r2: 0.2987, Test_r2: 0.334373
# Epoch [100/300], Train Loss: 2.5040, Test Loss: 2.4976, Train_r2: 0.3066, Test_r2: 0.356983
# Epoch [101/300], Train Loss: 2.4699, Test Loss: 2.4921, Train_r2: 0.3158, Test_r2: 0.347588
# Epoch [102/300], Train Loss: 2.5791, Test Loss: 2.6180, Train_r2: 0.2810, Test_r2: 0.334962
# Epoch [103/300], Train Loss: 2.4262, Test Loss: 2.4526, Train_r2: 0.3271, Test_r2: 0.365561
# Epoch [104/300], Train Loss: 2.3701, Test Loss: 2.2622, Train_r2: 0.3420, Test_r2: 0.424420
# Epoch [105/300], Train Loss: 2.1909, Test Loss: 2.2792, Train_r2: 0.3949, Test_r2: 0.411367
# Epoch [106/300], Train Loss: 2.1208, Test Loss: 2.1970, Train_r2: 0.4128, Test_r2: 0.435099
# Epoch [107/300], Train Loss: 2.0296, Test Loss: 1.8161, Train_r2: 0.4329, Test_r2: 0.535009
# Epoch [108/300], Train Loss: 1.7700, Test Loss: 1.6184, Train_r2: 0.5100, Test_r2: 0.583569
# Epoch [109/300], Train Loss: 1.5950, Test Loss: 1.4386, Train_r2: 0.5592, Test_r2: 0.629170
# Epoch [110/300], Train Loss: 1.2886, Test Loss: 1.2562, Train_r2: 0.6461, Test_r2: 0.678839
# Epoch [111/300], Train Loss: 1.1495, Test Loss: 1.0197, Train_r2: 0.6793, Test_r2: 0.740253
# Epoch [112/300], Train Loss: 0.8944, Test Loss: 0.7790, Train_r2: 0.7555, Test_r2: 0.803471
# Epoch [113/300], Train Loss: 0.7527, Test Loss: 0.7109, Train_r2: 0.7915, Test_r2: 0.815570
# Epoch [114/300], Train Loss: 0.6336, Test Loss: 0.6083, Train_r2: 0.8247, Test_r2: 0.843441
# Epoch [115/300], Train Loss: 0.5432, Test Loss: 0.5266, Train_r2: 0.8521, Test_r2: 0.864486
# Epoch [116/300], Train Loss: 0.5082, Test Loss: 0.5599, Train_r2: 0.8612, Test_r2: 0.857803
# Epoch [117/300], Train Loss: 0.4995, Test Loss: 0.5189, Train_r2: 0.8630, Test_r2: 0.867869
# Epoch [118/300], Train Loss: 0.4257, Test Loss: 0.4335, Train_r2: 0.8837, Test_r2: 0.890620
# Epoch [119/300], Train Loss: 0.3922, Test Loss: 0.3966, Train_r2: 0.8931, Test_r2: 0.899943
# Epoch [120/300], Train Loss: 0.3571, Test Loss: 0.4314, Train_r2: 0.9015, Test_r2: 0.889513
# Epoch [121/300], Train Loss: 0.3492, Test Loss: 0.4907, Train_r2: 0.9039, Test_r2: 0.873191
# Epoch [122/300], Train Loss: 0.3491, Test Loss: 0.3579, Train_r2: 0.9045, Test_r2: 0.910332
# Epoch [123/300], Train Loss: 0.3191, Test Loss: 0.3889, Train_r2: 0.9127, Test_r2: 0.901151
# Epoch [124/300], Train Loss: 0.2959, Test Loss: 0.2931, Train_r2: 0.9191, Test_r2: 0.928105
# Epoch [125/300], Train Loss: 0.2584, Test Loss: 0.2946, Train_r2: 0.9280, Test_r2: 0.924607
# Epoch [126/300], Train Loss: 0.2466, Test Loss: 0.2997, Train_r2: 0.9321, Test_r2: 0.924734
# Epoch [127/300], Train Loss: 0.3093, Test Loss: 0.2889, Train_r2: 0.9142, Test_r2: 0.926269
# Epoch [128/300], Train Loss: 0.2980, Test Loss: 0.3759, Train_r2: 0.9181, Test_r2: 0.902977
# Epoch [129/300], Train Loss: 0.2835, Test Loss: 0.2564, Train_r2: 0.9239, Test_r2: 0.934975
# Epoch [130/300], Train Loss: 0.2324, Test Loss: 0.2521, Train_r2: 0.9366, Test_r2: 0.934724
# Epoch [131/300], Train Loss: 0.2113, Test Loss: 0.3055, Train_r2: 0.9432, Test_r2: 0.921704
# Epoch [132/300], Train Loss: 0.2323, Test Loss: 0.2345, Train_r2: 0.9363, Test_r2: 0.940430
# Epoch [133/300], Train Loss: 0.1888, Test Loss: 0.2363, Train_r2: 0.9468, Test_r2: 0.939887
# Epoch [134/300], Train Loss: 0.1932, Test Loss: 0.2095, Train_r2: 0.9473, Test_r2: 0.946042
# Epoch [135/300], Train Loss: 0.1779, Test Loss: 0.2011, Train_r2: 0.9510, Test_r2: 0.948543
# Epoch [136/300], Train Loss: 0.1733, Test Loss: 0.1957, Train_r2: 0.9532, Test_r2: 0.950107
# Epoch [137/300], Train Loss: 0.1776, Test Loss: 0.2081, Train_r2: 0.9506, Test_r2: 0.946156
# Epoch [138/300], Train Loss: 0.1782, Test Loss: 0.1823, Train_r2: 0.9507, Test_r2: 0.952874
# Epoch [139/300], Train Loss: 0.1546, Test Loss: 0.1724, Train_r2: 0.9576, Test_r2: 0.956781
# Epoch [140/300], Train Loss: 0.1564, Test Loss: 0.1769, Train_r2: 0.9570, Test_r2: 0.955047
# Epoch [141/300], Train Loss: 0.1423, Test Loss: 0.1642, Train_r2: 0.9617, Test_r2: 0.958021
# Epoch [142/300], Train Loss: 0.1608, Test Loss: 0.1730, Train_r2: 0.9556, Test_r2: 0.955140
# Epoch [143/300], Train Loss: 0.1603, Test Loss: 0.2079, Train_r2: 0.9563, Test_r2: 0.947413
# Epoch [144/300], Train Loss: 0.1640, Test Loss: 0.1546, Train_r2: 0.9549, Test_r2: 0.960981
# Epoch [145/300], Train Loss: 0.1771, Test Loss: 0.1551, Train_r2: 0.9516, Test_r2: 0.960647
# Epoch [146/300], Train Loss: 0.1347, Test Loss: 0.1506, Train_r2: 0.9633, Test_r2: 0.961356
# Epoch [147/300], Train Loss: 0.1360, Test Loss: 0.1445, Train_r2: 0.9630, Test_r2: 0.963051
# Epoch [148/300], Train Loss: 0.1318, Test Loss: 0.1689, Train_r2: 0.9640, Test_r2: 0.956322
# Epoch [149/300], Train Loss: 0.1266, Test Loss: 0.1477, Train_r2: 0.9655, Test_r2: 0.961985
# Epoch [150/300], Train Loss: 0.1255, Test Loss: 0.1368, Train_r2: 0.9658, Test_r2: 0.965025
# Epoch [151/300], Train Loss: 0.1222, Test Loss: 0.1270, Train_r2: 0.9671, Test_r2: 0.967573
# Epoch [152/300], Train Loss: 0.1431, Test Loss: 0.1608, Train_r2: 0.9614, Test_r2: 0.958596
# Epoch [153/300], Train Loss: 0.1192, Test Loss: 0.1403, Train_r2: 0.9679, Test_r2: 0.964500
# Epoch [154/300], Train Loss: 0.1123, Test Loss: 0.1326, Train_r2: 0.9690, Test_r2: 0.966545
# Epoch [155/300], Train Loss: 0.1108, Test Loss: 0.1459, Train_r2: 0.9694, Test_r2: 0.962777
# Epoch [156/300], Train Loss: 0.1165, Test Loss: 0.1926, Train_r2: 0.9674, Test_r2: 0.950133
# Epoch [157/300], Train Loss: 0.1340, Test Loss: 0.1149, Train_r2: 0.9630, Test_r2: 0.970311
# Epoch [158/300], Train Loss: 0.1369, Test Loss: 0.1285, Train_r2: 0.9627, Test_r2: 0.966748
# Epoch [159/300], Train Loss: 0.1038, Test Loss: 0.1171, Train_r2: 0.9718, Test_r2: 0.969746
# Epoch [160/300], Train Loss: 0.1002, Test Loss: 0.1076, Train_r2: 0.9722, Test_r2: 0.972310
# Epoch [161/300], Train Loss: 0.0970, Test Loss: 0.1046, Train_r2: 0.9738, Test_r2: 0.973127
# Epoch [162/300], Train Loss: 0.1097, Test Loss: 0.1390, Train_r2: 0.9703, Test_r2: 0.964380
# Epoch [163/300], Train Loss: 0.1095, Test Loss: 0.1112, Train_r2: 0.9699, Test_r2: 0.970870
# Epoch [164/300], Train Loss: 0.0986, Test Loss: 0.0991, Train_r2: 0.9739, Test_r2: 0.974555
# Epoch [165/300], Train Loss: 0.0999, Test Loss: 0.1130, Train_r2: 0.9734, Test_r2: 0.970944
# Epoch [166/300], Train Loss: 0.0914, Test Loss: 0.1233, Train_r2: 0.9751, Test_r2: 0.968035
# Epoch [167/300], Train Loss: 0.0906, Test Loss: 0.0927, Train_r2: 0.9753, Test_r2: 0.976295
# Epoch [168/300], Train Loss: 0.0941, Test Loss: 0.0898, Train_r2: 0.9743, Test_r2: 0.977056
# Epoch [169/300], Train Loss: 0.1043, Test Loss: 0.0976, Train_r2: 0.9711, Test_r2: 0.975083
# Epoch [170/300], Train Loss: 0.0840, Test Loss: 0.0914, Train_r2: 0.9767, Test_r2: 0.975747
# Epoch [171/300], Train Loss: 0.0807, Test Loss: 0.0837, Train_r2: 0.9775, Test_r2: 0.977528
# Epoch [172/300], Train Loss: 0.0920, Test Loss: 0.1401, Train_r2: 0.9748, Test_r2: 0.963475
# Epoch [173/300], Train Loss: 0.1188, Test Loss: 0.1752, Train_r2: 0.9676, Test_r2: 0.955149
# Epoch [174/300], Train Loss: 0.0974, Test Loss: 0.0831, Train_r2: 0.9740, Test_r2: 0.979207
# Epoch [175/300], Train Loss: 0.0790, Test Loss: 0.0846, Train_r2: 0.9785, Test_r2: 0.978385
# Epoch [176/300], Train Loss: 0.0931, Test Loss: 0.1120, Train_r2: 0.9746, Test_r2: 0.971169
# Epoch [177/300], Train Loss: 0.0831, Test Loss: 0.0802, Train_r2: 0.9777, Test_r2: 0.978782
# Epoch [178/300], Train Loss: 0.0833, Test Loss: 0.0808, Train_r2: 0.9776, Test_r2: 0.979425
# Epoch [179/300], Train Loss: 0.0834, Test Loss: 0.0873, Train_r2: 0.9774, Test_r2: 0.977981
# Epoch [180/300], Train Loss: 0.0715, Test Loss: 0.0720, Train_r2: 0.9803, Test_r2: 0.981686
# Epoch [181/300], Train Loss: 0.0673, Test Loss: 0.0769, Train_r2: 0.9823, Test_r2: 0.980186
# Epoch [182/300], Train Loss: 0.0682, Test Loss: 0.0698, Train_r2: 0.9817, Test_r2: 0.981594
# Epoch [183/300], Train Loss: 0.0810, Test Loss: 0.0732, Train_r2: 0.9784, Test_r2: 0.981226
# Epoch [184/300], Train Loss: 0.0813, Test Loss: 0.0684, Train_r2: 0.9779, Test_r2: 0.982253
# Epoch [185/300], Train Loss: 0.0791, Test Loss: 0.0662, Train_r2: 0.9786, Test_r2: 0.983078
# Epoch [186/300], Train Loss: 0.0659, Test Loss: 0.0663, Train_r2: 0.9823, Test_r2: 0.983211
# Epoch [187/300], Train Loss: 0.0632, Test Loss: 0.0630, Train_r2: 0.9829, Test_r2: 0.983771
# Epoch [188/300], Train Loss: 0.0632, Test Loss: 0.0631, Train_r2: 0.9827, Test_r2: 0.983851
# Epoch [189/300], Train Loss: 0.0710, Test Loss: 0.0657, Train_r2: 0.9809, Test_r2: 0.983285
# Epoch [190/300], Train Loss: 0.0636, Test Loss: 0.0634, Train_r2: 0.9826, Test_r2: 0.983884
# Epoch [191/300], Train Loss: 0.0591, Test Loss: 0.0632, Train_r2: 0.9841, Test_r2: 0.983802
# Epoch [192/300], Train Loss: 0.0711, Test Loss: 0.0636, Train_r2: 0.9806, Test_r2: 0.983759
# Epoch [193/300], Train Loss: 0.0646, Test Loss: 0.0975, Train_r2: 0.9825, Test_r2: 0.973473
# Epoch [194/300], Train Loss: 0.0675, Test Loss: 0.0554, Train_r2: 0.9820, Test_r2: 0.986066
# Epoch [195/300], Train Loss: 0.0566, Test Loss: 0.0579, Train_r2: 0.9850, Test_r2: 0.985055
# Epoch [196/300], Train Loss: 0.0592, Test Loss: 0.0535, Train_r2: 0.9841, Test_r2: 0.986377
# Epoch [197/300], Train Loss: 0.0692, Test Loss: 0.0803, Train_r2: 0.9815, Test_r2: 0.979327
# Epoch [198/300], Train Loss: 0.0640, Test Loss: 0.0637, Train_r2: 0.9828, Test_r2: 0.983636
# Epoch [199/300], Train Loss: 0.0562, Test Loss: 0.0647, Train_r2: 0.9847, Test_r2: 0.983362
# Epoch [200/300], Train Loss: 0.0687, Test Loss: 0.0517, Train_r2: 0.9812, Test_r2: 0.986884
# Epoch [201/300], Train Loss: 0.0743, Test Loss: 0.0774, Train_r2: 0.9803, Test_r2: 0.980160
# Epoch [202/300], Train Loss: 0.0702, Test Loss: 0.0477, Train_r2: 0.9806, Test_r2: 0.987791
# Epoch [203/300], Train Loss: 0.0590, Test Loss: 0.0508, Train_r2: 0.9839, Test_r2: 0.986637
# Epoch [204/300], Train Loss: 0.0589, Test Loss: 0.0455, Train_r2: 0.9841, Test_r2: 0.988235
# Epoch [205/300], Train Loss: 0.0571, Test Loss: 0.0466, Train_r2: 0.9843, Test_r2: 0.988216
# Epoch [206/300], Train Loss: 0.0567, Test Loss: 0.0457, Train_r2: 0.9843, Test_r2: 0.988146
# Epoch [207/300], Train Loss: 0.0565, Test Loss: 0.0741, Train_r2: 0.9849, Test_r2: 0.981195
# Epoch [208/300], Train Loss: 0.0552, Test Loss: 0.0458, Train_r2: 0.9854, Test_r2: 0.987999
# Epoch [209/300], Train Loss: 0.0552, Test Loss: 0.0448, Train_r2: 0.9850, Test_r2: 0.988419
# Epoch [210/300], Train Loss: 0.0463, Test Loss: 0.0422, Train_r2: 0.9874, Test_r2: 0.989289
# Epoch [211/300], Train Loss: 0.0518, Test Loss: 0.0500, Train_r2: 0.9860, Test_r2: 0.987109
# Epoch [212/300], Train Loss: 0.0482, Test Loss: 0.0420, Train_r2: 0.9867, Test_r2: 0.989492
# Epoch [213/300], Train Loss: 0.0450, Test Loss: 0.0406, Train_r2: 0.9879, Test_r2: 0.989709
# Epoch [214/300], Train Loss: 0.0451, Test Loss: 0.0381, Train_r2: 0.9875, Test_r2: 0.990390
# Epoch [215/300], Train Loss: 0.0480, Test Loss: 0.0479, Train_r2: 0.9870, Test_r2: 0.987524
# Epoch [216/300], Train Loss: 0.0533, Test Loss: 0.0558, Train_r2: 0.9856, Test_r2: 0.986006
# Epoch [217/300], Train Loss: 0.0782, Test Loss: 0.0509, Train_r2: 0.9778, Test_r2: 0.986985
# Epoch [218/300], Train Loss: 0.0596, Test Loss: 0.0417, Train_r2: 0.9834, Test_r2: 0.989219
# Epoch [219/300], Train Loss: 0.0432, Test Loss: 0.0431, Train_r2: 0.9885, Test_r2: 0.988917
# Epoch [220/300], Train Loss: 0.0517, Test Loss: 0.0775, Train_r2: 0.9862, Test_r2: 0.980441
# Epoch [221/300], Train Loss: 0.0569, Test Loss: 0.0397, Train_r2: 0.9848, Test_r2: 0.989849
# Epoch [222/300], Train Loss: 0.0801, Test Loss: 0.1203, Train_r2: 0.9778, Test_r2: 0.968721
# Epoch [223/300], Train Loss: 0.0678, Test Loss: 0.1066, Train_r2: 0.9818, Test_r2: 0.972702
# Epoch [224/300], Train Loss: 0.0730, Test Loss: 0.1271, Train_r2: 0.9800, Test_r2: 0.966551
# Epoch [225/300], Train Loss: 0.0672, Test Loss: 0.0627, Train_r2: 0.9819, Test_r2: 0.983833
# Epoch [226/300], Train Loss: 0.0502, Test Loss: 0.0391, Train_r2: 0.9861, Test_r2: 0.989980
# Epoch [227/300], Train Loss: 0.0425, Test Loss: 0.0365, Train_r2: 0.9885, Test_r2: 0.990439
# Epoch [228/300], Train Loss: 0.0446, Test Loss: 0.0340, Train_r2: 0.9878, Test_r2: 0.991256
# Epoch [229/300], Train Loss: 0.0549, Test Loss: 0.0353, Train_r2: 0.9851, Test_r2: 0.990958
# Epoch [230/300], Train Loss: 0.0603, Test Loss: 0.0640, Train_r2: 0.9833, Test_r2: 0.983447
# Epoch [231/300], Train Loss: 0.0443, Test Loss: 0.0521, Train_r2: 0.9882, Test_r2: 0.986602
# Epoch [232/300], Train Loss: 0.0447, Test Loss: 0.0438, Train_r2: 0.9883, Test_r2: 0.988787
# Epoch [233/300], Train Loss: 0.0362, Test Loss: 0.0312, Train_r2: 0.9901, Test_r2: 0.992217
# Epoch [234/300], Train Loss: 0.0397, Test Loss: 0.0429, Train_r2: 0.9893, Test_r2: 0.988972
# Epoch [235/300], Train Loss: 0.0460, Test Loss: 0.0329, Train_r2: 0.9876, Test_r2: 0.991477
# Epoch [236/300], Train Loss: 0.0424, Test Loss: 0.0304, Train_r2: 0.9885, Test_r2: 0.992618
# Epoch [237/300], Train Loss: 0.0374, Test Loss: 0.0303, Train_r2: 0.9900, Test_r2: 0.992395
# Epoch [238/300], Train Loss: 0.0351, Test Loss: 0.0302, Train_r2: 0.9906, Test_r2: 0.991874
# Epoch [239/300], Train Loss: 0.0405, Test Loss: 0.0378, Train_r2: 0.9892, Test_r2: 0.990053
# Epoch [240/300], Train Loss: 0.0541, Test Loss: 0.0524, Train_r2: 0.9853, Test_r2: 0.986522
# Epoch [241/300], Train Loss: 0.0449, Test Loss: 0.0370, Train_r2: 0.9881, Test_r2: 0.990264
# Epoch [242/300], Train Loss: 0.0609, Test Loss: 0.1021, Train_r2: 0.9824, Test_r2: 0.974069
# Epoch [243/300], Train Loss: 0.0901, Test Loss: 0.0685, Train_r2: 0.9747, Test_r2: 0.982234
# Epoch [244/300], Train Loss: 0.0402, Test Loss: 0.0427, Train_r2: 0.9894, Test_r2: 0.989117
# Epoch [245/300], Train Loss: 0.0370, Test Loss: 0.0300, Train_r2: 0.9900, Test_r2: 0.992493
# Epoch [246/300], Train Loss: 0.0316, Test Loss: 0.0269, Train_r2: 0.9913, Test_r2: 0.993164
# Epoch [247/300], Train Loss: 0.0349, Test Loss: 0.0350, Train_r2: 0.9907, Test_r2: 0.991126
# Epoch [248/300], Train Loss: 0.0354, Test Loss: 0.0347, Train_r2: 0.9906, Test_r2: 0.991281
# Epoch [249/300], Train Loss: 0.0350, Test Loss: 0.0310, Train_r2: 0.9904, Test_r2: 0.992233
# Epoch [250/300], Train Loss: 0.0394, Test Loss: 0.0306, Train_r2: 0.9889, Test_r2: 0.992171
# Epoch [251/300], Train Loss: 0.0405, Test Loss: 0.0309, Train_r2: 0.9887, Test_r2: 0.991963
# Epoch [252/300], Train Loss: 0.0331, Test Loss: 0.0296, Train_r2: 0.9911, Test_r2: 0.992501
# Epoch [253/300], Train Loss: 0.0315, Test Loss: 0.0652, Train_r2: 0.9915, Test_r2: 0.983128
# Epoch [254/300], Train Loss: 0.0380, Test Loss: 0.0245, Train_r2: 0.9897, Test_r2: 0.993660
# Epoch [255/300], Train Loss: 0.0290, Test Loss: 0.0242, Train_r2: 0.9919, Test_r2: 0.993786
# Epoch [256/300], Train Loss: 0.0401, Test Loss: 0.0285, Train_r2: 0.9888, Test_r2: 0.992581
# Epoch [257/300], Train Loss: 0.0467, Test Loss: 0.0387, Train_r2: 0.9872, Test_r2: 0.990166
# Epoch [258/300], Train Loss: 0.0305, Test Loss: 0.0322, Train_r2: 0.9919, Test_r2: 0.991708
# Epoch [259/300], Train Loss: 0.0320, Test Loss: 0.0348, Train_r2: 0.9912, Test_r2: 0.991113
# Epoch [260/300], Train Loss: 0.0375, Test Loss: 0.0402, Train_r2: 0.9899, Test_r2: 0.989489
# Epoch [261/300], Train Loss: 0.0347, Test Loss: 0.0311, Train_r2: 0.9905, Test_r2: 0.991868
# Epoch [262/300], Train Loss: 0.0574, Test Loss: 0.0629, Train_r2: 0.9838, Test_r2: 0.983879
# Epoch [263/300], Train Loss: 0.0539, Test Loss: 0.0263, Train_r2: 0.9852, Test_r2: 0.993355
# Epoch [264/300], Train Loss: 0.0334, Test Loss: 0.0236, Train_r2: 0.9907, Test_r2: 0.994048
# Epoch [265/300], Train Loss: 0.0355, Test Loss: 0.0264, Train_r2: 0.9902, Test_r2: 0.993259
# Epoch [266/300], Train Loss: 0.0341, Test Loss: 0.0274, Train_r2: 0.9905, Test_r2: 0.992967
# Epoch [267/300], Train Loss: 0.0316, Test Loss: 0.0658, Train_r2: 0.9915, Test_r2: 0.983030
# Epoch [268/300], Train Loss: 0.0355, Test Loss: 0.0328, Train_r2: 0.9904, Test_r2: 0.991608
# Epoch [269/300], Train Loss: 0.0357, Test Loss: 0.0639, Train_r2: 0.9902, Test_r2: 0.982947
# Epoch [270/300], Train Loss: 0.0538, Test Loss: 0.0375, Train_r2: 0.9848, Test_r2: 0.990401
# Epoch [271/300], Train Loss: 0.0279, Test Loss: 0.0255, Train_r2: 0.9925, Test_r2: 0.993510
# Epoch [272/300], Train Loss: 0.0253, Test Loss: 0.0243, Train_r2: 0.9930, Test_r2: 0.993704
# Epoch [273/300], Train Loss: 0.0311, Test Loss: 0.0235, Train_r2: 0.9917, Test_r2: 0.993838
# Epoch [274/300], Train Loss: 0.0345, Test Loss: 0.0275, Train_r2: 0.9904, Test_r2: 0.992975
# Epoch [275/300], Train Loss: 0.0490, Test Loss: 0.0419, Train_r2: 0.9864, Test_r2: 0.989398
# Epoch [276/300], Train Loss: 0.0622, Test Loss: 0.0488, Train_r2: 0.9827, Test_r2: 0.987348
# Epoch [277/300], Train Loss: 0.0285, Test Loss: 0.0340, Train_r2: 0.9921, Test_r2: 0.991174
# Epoch [278/300], Train Loss: 0.0451, Test Loss: 0.0266, Train_r2: 0.9872, Test_r2: 0.992935
# Epoch [279/300], Train Loss: 0.0232, Test Loss: 0.0253, Train_r2: 0.9937, Test_r2: 0.993580
# Epoch [280/300], Train Loss: 0.0305, Test Loss: 0.0205, Train_r2: 0.9916, Test_r2: 0.994761
# Epoch [281/300], Train Loss: 0.0318, Test Loss: 0.0293, Train_r2: 0.9913, Test_r2: 0.992417
# Epoch [282/300], Train Loss: 0.0317, Test Loss: 0.0275, Train_r2: 0.9914, Test_r2: 0.992895
# Epoch [283/300], Train Loss: 0.0266, Test Loss: 0.0260, Train_r2: 0.9927, Test_r2: 0.993244
# Epoch [284/300], Train Loss: 0.0339, Test Loss: 0.0259, Train_r2: 0.9906, Test_r2: 0.993238
# Epoch [285/300], Train Loss: 0.0288, Test Loss: 0.0347, Train_r2: 0.9922, Test_r2: 0.991246
# Epoch [286/300], Train Loss: 0.0257, Test Loss: 0.0200, Train_r2: 0.9929, Test_r2: 0.994878
# Epoch [287/300], Train Loss: 0.0352, Test Loss: 0.0297, Train_r2: 0.9902, Test_r2: 0.992564
# Epoch [288/300], Train Loss: 0.0306, Test Loss: 0.0257, Train_r2: 0.9917, Test_r2: 0.993315
# Epoch [289/300], Train Loss: 0.0392, Test Loss: 0.0244, Train_r2: 0.9891, Test_r2: 0.993323
# Epoch [290/300], Train Loss: 0.0551, Test Loss: 0.0358, Train_r2: 0.9849, Test_r2: 0.990736
# Epoch [291/300], Train Loss: 0.0389, Test Loss: 0.0285, Train_r2: 0.9892, Test_r2: 0.992697
# Epoch [292/300], Train Loss: 0.0387, Test Loss: 0.0208, Train_r2: 0.9891, Test_r2: 0.994599
# Epoch [293/300], Train Loss: 0.0278, Test Loss: 0.0972, Train_r2: 0.9923, Test_r2: 0.974755
# Epoch [294/300], Train Loss: 0.0388, Test Loss: 0.0190, Train_r2: 0.9894, Test_r2: 0.995201
# Epoch [295/300], Train Loss: 0.0212, Test Loss: 0.0193, Train_r2: 0.9942, Test_r2: 0.995173
# Epoch [296/300], Train Loss: 0.0244, Test Loss: 0.0227, Train_r2: 0.9934, Test_r2: 0.994136
# Epoch [297/300], Train Loss: 0.0361, Test Loss: 0.0558, Train_r2: 0.9895, Test_r2: 0.985758
# Epoch [298/300], Train Loss: 0.0318, Test Loss: 0.0214, Train_r2: 0.9914, Test_r2: 0.994335
# Epoch [299/300], Train Loss: 0.0242, Test Loss: 0.0265, Train_r2: 0.9936, Test_r2: 0.993224
# Epoch [300/300], Train Loss: 0.0228, Test Loss: 0.0181, Train_r2: 0.9937, Test_r2: 0.995418

# %%
plt.style.use('dark_background')
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

axs[0].plot(train_losses, '-o', color='magenta', label='Train Losses')
axs[0].plot(test_losses, '-o', color='orange', label='Test Losses')
axs[0].set_title("Train vs Test Losses")
axs[0].set_ylabel("MSELosses averaged across batches")
axs[0].set_xlabel("Epochs")
axs[0].text(160, 14, f"Final: {train_losses[-1]:.4f}, {test_losses[-1]:.4f}")
axs[0].grid(alpha=0.2)
axs[0].legend()

axs[1].plot(train_r2, '-o', color='magenta', label='Train R2')
axs[1].plot(test_r2, '-o', color='orange', label='Test R2')
axs[1].set_title("Train vs Test R2")
axs[1].set_ylabel("R2 score averaged across batches")
axs[1].set_xlabel("Epochs")
axs[1].grid(alpha=0.2)
axs[1].text(160, 0.2, f"Final: {train_r2[-1]:.4f}, {test_r2[-1]:.4f}")
axs[1].legend()
plt.suptitle('Model trained on varying sequence length.', y=0)
plt.show()

# %%
torch.save(model.state_dict(), "D:/Assignments/Autonomize/model_v2.pt")

# %% [markdown]
# ### Approach 2:
# First padding the variable length sequences to the maximum size in the batch then using `pack_padded_sequence` and `pad_packed_sequence` operations in the forward method of the model architecture.

# %% [markdown]
# Note: The cells below are copied from '_CpG_Detector_copy.ipynb', where the actual training and experimentation of this approach was done.

# %%
# hint we will need following imports
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence

# %%
# DO NOT CHANGE HERE
random.seed(13)

# Use this for getting x label
def rand_sequence_var_len(n_seqs: int, lb: int=16, ub: int=128) -> Sequence[int]:
    for i in range(n_seqs):
        seq_len = random.randint(lb, ub)
        yield [random.randint(1, 5) for _ in range(seq_len)]


# Use this for getting y label
def count_cpgs(seq: str) -> int:
    cgs = 0
    for i in range(0, len(seq) - 1):
        dimer = seq[i:i+2]
        # note that seq is a string, not a list
        if dimer == "CG":
            cgs += 1
    return cgs


# Alphabet helpers   
alphabet = 'NACGT'
dna2int = {a: i for a, i in zip(alphabet, range(1, 6))}
int2dna = {i: a for a, i in zip(alphabet, range(1, 6))}
dna2int.update({"pad": 0})
int2dna.update({0: "<pad>"})

intseq_to_dnaseq = partial(map, int2dna.get)
dnaseq_to_intseq = partial(map, dna2int.get)

# %%
# TODO complete the task based on the change
def prepare_data(num_samples=100, min_len=16, max_len=128):
    # TODO prepared the training and test data
    # you need to call rand_sequence and count_cpgs here to create the dataset
    #step 1
    X_dna_seqs_train = list(rand_sequence_var_len(num_samples, min_len, max_len))
    #step 2
    temp = list(map(intseq_to_dnaseq, X_dna_seqs_train))
    dna_seqs = [''.join(seq) for seq in temp]
    #step3
    y_dna_seqs = [count_cpgs(seq) for seq in dna_seqs]
    
    return X_dna_seqs_train, y_dna_seqs
    
    
min_len, max_len = 64, 128
train_x, train_y = prepare_data(2048, min_len, max_len)
test_x, test_y = prepare_data(512, min_len, max_len)

# %%
print(len(train_x), len(train_y), len(test_x), len(test_y))

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, lists, labels) -> None:
        self.lists = lists
        self.labels = labels

    def __getitem__(self, index):
        # Convert sequences to LongTensor
        sequences_tensor = torch.LongTensor(self.lists[index])

        # Convert labels to FloatTensor with unsqueeze to make it 2D
        label_tensor = torch.tensor(self.labels[index], dtype=torch.float32)

        return sequences_tensor, label_tensor

    def __len__(self):
        return len(self.lists)

    
# this will be a collate_fn for dataloader to pad sequence  
class PadSequence:
    def __init__(self, padding_value=0) -> None:
        self.padding_value = padding_value

    def __call__(self, batch):
        # Sort the batch by sequence length in descending order
        batch = sorted(batch, key=lambda x: len(x[0]), reverse=True)
        # Get the sequence and labels from the sorted batch
        sequences, labels = zip(*batch)

        # Get lengths
        lengths = [len(seq) for seq in sequences]

        # Pad the sequence
        padded_sequences = pad_sequence(sequences, batch_first=True, padding_value=self.padding_value)
        
        return padded_sequences, torch.tensor(labels), torch.tensor(lengths)

# %%
# some config
LSTM_HIDDEN = 16
LSTM_LAYER = 3
BATCH_SIZE = 128
LEARNING_RATE = 0.001
NUM_EPOCHS = 300
VOCAB_SIZE = 6
OUTPUT_SIZE = 1

# %%
train_dataset = MyDataset(train_x, train_y)
test_dataset = MyDataset(test_x, test_y)

pad_sequence_collate_fn = PadSequence(padding_value=dna2int['pad'])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, collate_fn=pad_sequence_collate_fn, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, collate_fn=pad_sequence_collate_fn, shuffle=True)

# %%
class CpGPredictor(torch.nn.Module):
    ''' Simple model that uses a LSTM to count the number of CpGs in a sequence '''
    def __init__(self, vocab_size, embedding_dim, hidden_size, num_layers, output_size):
        super(CpGPredictor, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_size = output_size
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_size, num_layers, batch_first=True)
        self.classifier = nn.Linear(hidden_size, output_size)

    def forward(self, x, lengths, hc=None):

        # Initialize hidden state and cell state if not provided
        if hc is None:
            hc = self.init_hidden(lengths.size(0))

        # Embedding layer
        embedded_x = self.embedding(x)
        
        # Pack the embedded input
        packed_embedded = pack_padded_sequence(embedded_x, lengths, batch_first=True, enforce_sorted=False)

        # LSTM layer
        packed_out, _ = self.lstm(packed_embedded, hc)

        # Unpack the output of the LSTM layer
        out, _ = pad_packed_sequence(packed_out, batch_first=True)

        # Use the output from the last time step for classification
        out = self.classifier(out[:, -1, :])

        return out
    
    def init_hidden(self, batch_size):
        # Initialize hidden state and cell state with zeros
        return (torch.zeros(self.num_layers, batch_size, self.hidden_size),
                torch.zeros(self.num_layers, batch_size, self.hidden_size))

# %%
# init model / loss function / optimizer etc.
model = CpGPredictor(vocab_size=VOCAB_SIZE, embedding_dim=16, hidden_size=LSTM_HIDDEN, num_layers=LSTM_LAYER, output_size=OUTPUT_SIZE)
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
# training (you can modify the code below)

# Initialize Losses
train_losses = []
test_losses = []

train_r2 = []
test_r2 = []

for epoch in range(NUM_EPOCHS):
    
    # Set the model on training mode.
    model.train()

    # Initialize batch losses
    train_batch_losses = []
    test_batch_losses = []

    train_batch_r2 = []
    test_batch_r2 = []
    
    for X, y, lengths in train_loader:

        # Initialize hidden state
        hc = model.init_hidden(lengths.size(0))

        y_hat = model(X, lengths, hc)

        # Compute Loss
        loss = loss_fn(y_hat, y.unsqueeze(1))

        # Compute r2
        r2 = r2_score(y.detach().numpy(), y_hat.detach().numpy())

        # Backprop and Optimzation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Store the batch loss
        train_batch_losses.append(loss.item())
        train_batch_r2.append(r2)
    
    # Average the batch losses and store as a global loss
    train_losses.append(np.mean(train_batch_losses))
    train_r2.append(np.mean(train_batch_r2))

    # Set the model on evaluation mode.
    model.eval()
    for X, y, lengths in test_loader:
        with torch.no_grad():
            # Initialize hidden state
            hc = model.init_hidden(lengths.size(0))

            y_hat = model(X,lengths, hc)
            loss = loss_fn(y_hat, y.unsqueeze(1))
            r2 = r2_score(y.detach().numpy(), y_hat.detach().numpy())

            test_batch_losses.append(loss.item())
            test_batch_r2.append(r2)

    # Average loss across the batches
    test_losses.append(np.mean(test_batch_losses))
    test_r2.append(np.mean(test_batch_r2))
    
    print(f'Epoch [{epoch + 1}/{NUM_EPOCHS}], Train Loss: {train_losses[-1]:.4f}, Test Loss: {test_losses[-1]:.4f}, Train_r2: {train_r2[-1]:.4f}, Test_r2: {test_r2[-1]:4f}')
